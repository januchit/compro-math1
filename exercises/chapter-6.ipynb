# %% [markdown]
# # 040223101 การเขียนโปรแกรมคอมพิวเตอร์สำหรับคณิตศาสตร์ 1
# ## (Computer Programming for Mathematics 1)
#
# # แบบฝึกหัด บทที่ 6: โครงสร้างข้อมูลแบบลิสต์
# ### Lists
#
# **ผู้สอน:** รศ.ดร.อนุชิต จิตพัฒนกุล
# ภาควิชาคณิตศาสตร์ คณะวิทยาศาสตร์ประยุกต์  มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าพระนครเหนือ
#
# ---
#
# ### 📝 คำชี้แจง
# - ให้นักศึกษาเขียนโปรแกรมภาษา Python แก้โจทย์แต่ละข้อในเซลล์โค้ดที่เว้นว่างไว้ใต้โจทย์
# - กดปุ่ม **▶ Run** (หรือ Shift+Enter) เพื่อรันโค้ดและตรวจผลลัพธ์
# - โจทย์แบ่งเป็น 3 ระดับจากง่ายไปยาก ควรทำไล่ตามลำดับ
# - เขียนชื่อ-รหัสนักศึกษาของคุณในเซลล์ด้านล่างก่อนเริ่มทำ

# %%
# ✏️ กรอกข้อมูลของคุณ
student_name = ""   # ชื่อ-นามสกุล
student_id = ""     # รหัสนักศึกษา
print("ผู้ทำแบบฝึกหัด:", student_name, student_id)

# %% [markdown]
# ---
# ## ระดับที่ 1 — พื้นฐาน (Basic)
# _ฝึกใช้คำสั่งและไวยากรณ์พื้นฐานของบทนี้ให้คล่อง_

# %% [markdown]
# **ข้อ 1.** เขียนโปรแกรมสร้างลิสต์ [10, 20, 30, 40, 50] แล้วแสดงสมาชิกตัวแรกและตัวสุดท้าย

# %%
# ✍️ เขียนโค้ดข้อ 1 ที่นี่

# %% [markdown]
# **ข้อ 2.** เขียนโปรแกรมสร้างลิสต์ของชื่อผลไม้ 3 ชนิด แล้วแสดงทั้งลิสต์

# %%
# ✍️ เขียนโค้ดข้อ 2 ที่นี่

# %% [markdown]
# **ข้อ 3.** เขียนโปรแกรมสร้างลิสต์เลข 5 ตัว แล้วแสดงจำนวนสมาชิกด้วย len()

# %%
# ✍️ เขียนโค้ดข้อ 3 ที่นี่

# %% [markdown]
# **ข้อ 4.** เขียนโปรแกรมสร้างลิสต์ [1,2,3,4,5] แล้วแสดงผลรวมด้วย sum()

# %%
# ✍️ เขียนโค้ดข้อ 4 ที่นี่

# %% [markdown]
# **ข้อ 5.** เขียนโปรแกรมสร้างลิสต์ [4,8,15,16,23,42] แล้วแสดงค่ามากสุดและน้อยสุด

# %%
# ✍️ เขียนโค้ดข้อ 5 ที่นี่

# %% [markdown]
# **ข้อ 6.** เขียนโปรแกรมสร้างลิสต์เลข 5 ตัว แล้วแสดงค่าเฉลี่ย

# %%
# ✍️ เขียนโค้ดข้อ 6 ที่นี่

# %% [markdown]
# **ข้อ 7.** เขียนโปรแกรมสร้างลิสต์ว่าง แล้วเพิ่มเลข 1, 2, 3 ด้วย append แล้วแสดงลิสต์

# %%
# ✍️ เขียนโค้ดข้อ 7 ที่นี่

# %% [markdown]
# **ข้อ 8.** เขียนโปรแกรมสร้างลิสต์ [5,3,8,1,9] แล้วเรียงจากน้อยไปมากด้วย sort

# %%
# ✍️ เขียนโค้ดข้อ 8 ที่นี่

# %% [markdown]
# **ข้อ 9.** เขียนโปรแกรมสร้างลิสต์ [1,2,3,4,5] แล้วกลับลำดับด้วย reverse

# %%
# ✍️ เขียนโค้ดข้อ 9 ที่นี่

# %% [markdown]
# **ข้อ 10.** เขียนโปรแกรมสร้างลิสต์ [10,20,30,40,50] แล้วแสดงสมาชิกตัวที่ 2 ถึง 4 ด้วย slicing

# %%
# ✍️ เขียนโค้ดข้อ 10 ที่นี่

# %% [markdown]
# **ข้อ 11.** เขียนโปรแกรมวนแสดงสมาชิกทุกตัวในลิสต์ [2,4,6,8] บรรทัดละตัวด้วยลูป for

# %%
# ✍️ เขียนโค้ดข้อ 11 ที่นี่

# %% [markdown]
# **ข้อ 12.** เขียนโปรแกรมสร้างลิสต์ [7,7,3,7,1] แล้วนับจำนวน 7 ด้วย count

# %%
# ✍️ เขียนโค้ดข้อ 12 ที่นี่

# %% [markdown]
# **ข้อ 13.** เขียนโปรแกรมสร้างลิสต์ [100,200,300] แล้วแทรกค่า 150 ที่ตำแหน่งดัชนี 1

# %%
# ✍️ เขียนโค้ดข้อ 13 ที่นี่

# %% [markdown]
# **ข้อ 14.** เขียนโปรแกรมสร้างลิสต์ ['a','b','c','d'] แล้วลบ 'c' ด้วย remove

# %%
# ✍️ เขียนโค้ดข้อ 14 ที่นี่

# %% [markdown]
# **ข้อ 15.** เขียนโปรแกรมสร้างลิสต์ [10,20,30] แล้วเปลี่ยนสมาชิกตัวแรกเป็น 99

# %%
# ✍️ เขียนโค้ดข้อ 15 ที่นี่

# %% [markdown]
# **ข้อ 16.** เขียนโปรแกรมสร้างลิสต์ [3,1,4,1,5] แล้วแสดงดัชนีของค่า 4 ด้วย index

# %%
# ✍️ เขียนโค้ดข้อ 16 ที่นี่

# %% [markdown]
# **ข้อ 17.** เขียนโปรแกรมสร้างลิสต์เลข 1 ถึง 5 ด้วยลูป for และ append

# %%
# ✍️ เขียนโค้ดข้อ 17 ที่นี่

# %% [markdown]
# **ข้อ 18.** เขียนโปรแกรมสร้างลิสต์ [10,20,30,40,50] แล้วแสดงสมาชิก 3 ตัวแรกด้วย slicing

# %%
# ✍️ เขียนโค้ดข้อ 18 ที่นี่

# %% [markdown]
# **ข้อ 19.** เขียนโปรแกรมสร้างลิสต์ [1,2,3] และ [4,5,6] แล้วต่อกันด้วยเครื่องหมาย +

# %%
# ✍️ เขียนโค้ดข้อ 19 ที่นี่

# %% [markdown]
# **ข้อ 20.** เขียนโปรแกรมสร้างลิสต์ [5,10,15] แล้วลบสมาชิกตัวสุดท้ายด้วย pop

# %%
# ✍️ เขียนโค้ดข้อ 20 ที่นี่

# %% [markdown]
# ---
# ## ระดับที่ 2 — ปานกลาง (Intermediate)
# _ประยุกต์ความรู้แก้โจทย์ที่ซับซ้อนขึ้นและผสมหลายแนวคิด_

# %% [markdown]
# **ข้อ 21.** เขียนโปรแกรมรับตัวเลข 5 จำนวนเก็บในลิสต์ แล้วแสดงผลรวม ค่ามากสุด และน้อยสุด

# %%
# ✍️ เขียนโค้ดข้อ 21 ที่นี่

# %% [markdown]
# **ข้อ 22.** เขียนโปรแกรมนับจำนวนเลขคู่และคี่ในลิสต์ [12,7,5,8,20,3,14]

# %%
# ✍️ เขียนโค้ดข้อ 22 ที่นี่

# %% [markdown]
# **ข้อ 23.** เขียนโปรแกรมสร้างลิสต์กำลังสองของเลข 1 ถึง 10 แล้วแสดงผลรวม

# %%
# ✍️ เขียนโค้ดข้อ 23 ที่นี่

# %% [markdown]
# **ข้อ 24.** เขียนโปรแกรมหาผลรวมของสมาชิกในลิสต์โดยไม่ใช้ sum() (ใช้ลูป)

# %%
# ✍️ เขียนโค้ดข้อ 24 ที่นี่

# %% [markdown]
# **ข้อ 25.** เขียนโปรแกรมหาค่ามากที่สุดในลิสต์โดยไม่ใช้ max() (ใช้ลูป)

# %%
# ✍️ เขียนโค้ดข้อ 25 ที่นี่

# %% [markdown]
# **ข้อ 26.** เขียนโปรแกรมรับตัวเลข 5 จำนวน แล้วแสดงลิสต์ที่เรียงจากมากไปน้อย

# %%
# ✍️ เขียนโค้ดข้อ 26 ที่นี่

# %% [markdown]
# **ข้อ 27.** เขียนโปรแกรมหาค่าเฉลี่ยและส่วนเบี่ยงเบนมาตรฐานของลิสต์ [4,8,15,16,23,42]

# %%
# ✍️ เขียนโค้ดข้อ 27 ที่นี่

# %% [markdown]
# **ข้อ 28.** เขียนโปรแกรมสร้างลิสต์เลขคู่ตั้งแต่ 2 ถึง 20 ด้วยลูป

# %%
# ✍️ เขียนโค้ดข้อ 28 ที่นี่

# %% [markdown]
# **ข้อ 29.** เขียนโปรแกรมนับจำนวนสมาชิกที่มากกว่าค่าเฉลี่ยในลิสต์ [10,20,30,40,50]

# %%
# ✍️ เขียนโค้ดข้อ 29 ที่นี่

# %% [markdown]
# **ข้อ 30.** เขียนโปรแกรมหาผลคูณของสมาชิกทุกตัวในลิสต์ [1,2,3,4,5]

# %%
# ✍️ เขียนโค้ดข้อ 30 ที่นี่

# %% [markdown]
# **ข้อ 31.** เขียนโปรแกรมรวมสองลิสต์ [1,2,3] และ [4,5,6] เป็นลิสต์เดียวด้วยลูปและ append

# %%
# ✍️ เขียนโค้ดข้อ 31 ที่นี่

# %% [markdown]
# **ข้อ 32.** เขียนโปรแกรมหาผลรวมของสมาชิกที่อยู่ตำแหน่งดัชนีคู่ในลิสต์ [10,20,30,40,50,60]

# %%
# ✍️ เขียนโค้ดข้อ 32 ที่นี่

# %% [markdown]
# **ข้อ 33.** เขียนโปรแกรมแสดงสมาชิกของลิสต์ [5,10,15,20] พร้อมดัชนีกำกับด้วย enumerate

# %%
# ✍️ เขียนโค้ดข้อ 33 ที่นี่

# %% [markdown]
# **ข้อ 34.** เขียนโปรแกรมหาว่าค่า 25 อยู่ในลิสต์ [10,25,30,25,40] กี่ครั้ง

# %%
# ✍️ เขียนโค้ดข้อ 34 ที่นี่

# %% [markdown]
# **ข้อ 35.** เขียนโปรแกรมสร้างลิสต์เลขที่หารด้วย 3 ลงตัวในช่วง 1 ถึง 30

# %%
# ✍️ เขียนโค้ดข้อ 35 ที่นี่

# %% [markdown]
# **ข้อ 36.** เขียนโปรแกรมหาช่วง (range) ของลิสต์ คือ ค่ามากสุดลบค่าน้อยสุด ของ [12,5,8,20,3]

# %%
# ✍️ เขียนโค้ดข้อ 36 ที่นี่

# %% [markdown]
# **ข้อ 37.** เขียนโปรแกรมคัดลอกเฉพาะเลขบวกจากลิสต์ [-3,5,-1,8,0,7] ไปยังลิสต์ใหม่

# %%
# ✍️ เขียนโค้ดข้อ 37 ที่นี่

# %% [markdown]
# **ข้อ 38.** เขียนโปรแกรมหาผลรวมและจำนวนของสมาชิกที่เป็นเลขคี่ในลิสต์ [1,2,3,4,5,6,7]

# %%
# ✍️ เขียนโค้ดข้อ 38 ที่นี่

# %% [markdown]
# **ข้อ 39.** เขียนโปรแกรมแทนที่สมาชิกที่เป็นเลขลบในลิสต์ [3,-2,5,-7,1] ด้วย 0

# %%
# ✍️ เขียนโค้ดข้อ 39 ที่นี่

# %% [markdown]
# **ข้อ 40.** เขียนโปรแกรมหาค่ามัธยฐานของลิสต์ที่มีจำนวนสมาชิกเป็นเลขคี่ [7,1,5,3,9]

# %%
# ✍️ เขียนโค้ดข้อ 40 ที่นี่

# %% [markdown]
# ---
# ## ระดับที่ 3 — ท้าทาย (Challenge)
# _โจทย์ประยุกต์เชิงคณิตศาสตร์และตรรกะที่ต้องคิดวิเคราะห์_

# %% [markdown]
# **ข้อ 41.** เขียนโปรแกรมหาค่าที่ปรากฏบ่อยที่สุด (ฐานนิยม) ในลิสต์ [1,3,3,7,3,1,7]

# %%
# ✍️ เขียนโค้ดข้อ 41 ที่นี่

# %% [markdown]
# **ข้อ 42.** เขียนโปรแกรมลบค่าซ้ำออกจากลิสต์ [1,2,2,3,3,3,4] โดยสร้างลิสต์ใหม่ที่ไม่มีค่าซ้ำ

# %%
# ✍️ เขียนโค้ดข้อ 42 ที่นี่

# %% [markdown]
# **ข้อ 43.** เขียนโปรแกรมเรียงลิสต์ [5,2,8,1,9,3] จากน้อยไปมากด้วยอัลกอริทึม bubble sort (ไม่ใช้ sort)

# %%
# ✍️ เขียนโค้ดข้อ 43 ที่นี่

# %% [markdown]
# **ข้อ 44.** เขียนโปรแกรมหาผลคูณจุด (dot product) ของเวกเตอร์ [1,2,3] กับ [4,5,6]

# %%
# ✍️ เขียนโค้ดข้อ 44 ที่นี่

# %% [markdown]
# **ข้อ 45.** เขียนโปรแกรมหาสมาชิกที่มากเป็นอันดับสองในลิสต์ [10,5,20,8,15] (ไม่ใช้ sort)

# %%
# ✍️ เขียนโค้ดข้อ 45 ที่นี่

# %% [markdown]
# **ข้อ 46.** เขียนโปรแกรมรวมสองลิสต์ที่เรียงแล้ว [1,3,5] และ [2,4,6] ให้เป็นลิสต์ที่เรียงแล้ว

# %%
# ✍️ เขียนโค้ดข้อ 46 ที่นี่

# %% [markdown]
# **ข้อ 47.** เขียนโปรแกรมหาผลรวมสะสมของลิสต์ [1,2,3,4,5] ให้ได้ [1,3,6,10,15]

# %%
# ✍️ เขียนโค้ดข้อ 47 ที่นี่

# %% [markdown]
# **ข้อ 48.** เขียนโปรแกรมตรวจว่าลิสต์ [1,2,3,2,1] เป็นพาลินโดรมหรือไม่

# %%
# ✍️ เขียนโค้ดข้อ 48 ที่นี่

# %% [markdown]
# **ข้อ 49.** เขียนโปรแกรมหาสมาชิกที่เป็นจำนวนเฉพาะในลิสต์ [4,7,10,13,15,17]

# %%
# ✍️ เขียนโค้ดข้อ 49 ที่นี่

# %% [markdown]
# **ข้อ 50.** เขียนโปรแกรมแบ่งลิสต์ [1,2,3,4,5,6] เป็นลิสต์ของเลขคู่และลิสต์ของเลขคี่

# %%
# ✍️ เขียนโค้ดข้อ 50 ที่นี่
