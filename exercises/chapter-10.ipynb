# %% [markdown]
# # 040223101 การเขียนโปรแกรมคอมพิวเตอร์สำหรับคณิตศาสตร์ 1
# ## (Computer Programming for Mathematics 1)
#
# # แบบฝึกหัด บทที่ 10: การคำนวณเชิงตัวเลขด้วย NumPy
# ### Numerical Computing (NumPy)
#
# **ผู้สอน:** รศ.ดร.อนุชิต จิตพัฒนกุล
# ภาควิชาคณิตศาสตร์ คณะวิทยาศาสตร์ประยุกต์  มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าพระนครเหนือ
#
# ---
#
# ### 📝 คำชี้แจง
# - ให้นักศึกษาเขียนโปรแกรมภาษา Python แก้โจทย์แต่ละข้อในเซลล์โค้ดที่เว้นว่างไว้ใต้โจทย์
# - กดปุ่ม **▶ Run** (หรือ Shift+Enter) เพื่อรันโค้ดและตรวจผลลัพธ์
# - โจทย์แบ่งเป็น 3 ระดับจากง่ายไปยาก ควรทำไล่ตามลำดับ
# - เขียนชื่อ-รหัสนักศึกษาของคุณในเซลล์ด้านล่างก่อนเริ่มทำ

# %%
# ✏️ กรอกข้อมูลของคุณ
student_name = ""   # ชื่อ-นามสกุล
student_id = ""     # รหัสนักศึกษา
print("ผู้ทำแบบฝึกหัด:", student_name, student_id)

# %% [markdown]
# ---
# ## ระดับที่ 1 — พื้นฐาน (Basic)
# _ฝึกใช้คำสั่งและไวยากรณ์พื้นฐานของบทนี้ให้คล่อง_

# %% [markdown]
# **ข้อ 1.** เขียนโปรแกรมนำเข้า numpy เป็น np แล้วสร้างอาร์เรย์จากลิสต์ [1,2,3,4,5] และแสดงผล

# %%
# ✍️ เขียนโค้ดข้อ 1 ที่นี่

# %% [markdown]
# **ข้อ 2.** เขียนโปรแกรมสร้างอาร์เรย์ศูนย์จำนวน 5 ตัวด้วย np.zeros

# %%
# ✍️ เขียนโค้ดข้อ 2 ที่นี่

# %% [markdown]
# **ข้อ 3.** เขียนโปรแกรมสร้างอาร์เรย์หนึ่งจำนวน 4 ตัวด้วย np.ones

# %%
# ✍️ เขียนโค้ดข้อ 3 ที่นี่

# %% [markdown]
# **ข้อ 4.** เขียนโปรแกรมสร้างอาร์เรย์เลข 1 ถึง 10 ด้วย np.arange

# %%
# ✍️ เขียนโค้ดข้อ 4 ที่นี่

# %% [markdown]
# **ข้อ 5.** เขียนโปรแกรมสร้างอาร์เรย์ 5 ค่าเท่าระยะในช่วง 0 ถึง 1 ด้วย np.linspace

# %%
# ✍️ เขียนโค้ดข้อ 5 ที่นี่

# %% [markdown]
# **ข้อ 6.** เขียนโปรแกรมสร้างอาร์เรย์ [10,20,30,40] แล้วแสดงผลรวมด้วย sum()

# %%
# ✍️ เขียนโค้ดข้อ 6 ที่นี่

# %% [markdown]
# **ข้อ 7.** เขียนโปรแกรมสร้างอาร์เรย์ [4,8,15,16,23,42] แล้วแสดงค่าเฉลี่ยด้วย mean()

# %%
# ✍️ เขียนโค้ดข้อ 7 ที่นี่

# %% [markdown]
# **ข้อ 8.** เขียนโปรแกรมสร้างอาร์เรย์ [3,1,4,1,5,9] แล้วแสดงค่ามากสุดและน้อยสุด

# %%
# ✍️ เขียนโค้ดข้อ 8 ที่นี่

# %% [markdown]
# **ข้อ 9.** เขียนโปรแกรมสร้างอาร์เรย์ [1,2,3,4] แล้วบวกด้วย 10 ทุกสมาชิก

# %%
# ✍️ เขียนโค้ดข้อ 9 ที่นี่

# %% [markdown]
# **ข้อ 10.** เขียนโปรแกรมสร้างอาร์เรย์ [1,2,3,4] แล้วคูณด้วย 2 ทุกสมาชิก

# %%
# ✍️ เขียนโค้ดข้อ 10 ที่นี่

# %% [markdown]
# **ข้อ 11.** เขียนโปรแกรมสร้างอาร์เรย์ [1,2,3,4,5] แล้วแสดงกำลังสองของทุกสมาชิก

# %%
# ✍️ เขียนโค้ดข้อ 11 ที่นี่

# %% [markdown]
# **ข้อ 12.** เขียนโปรแกรมสร้างอาร์เรย์ [1,4,9,16] แล้วหารากที่สองของทุกสมาชิกด้วย np.sqrt

# %%
# ✍️ เขียนโค้ดข้อ 12 ที่นี่

# %% [markdown]
# **ข้อ 13.** เขียนโปรแกรมสร้างอาร์เรย์สองมิติ [[1,2,3],[4,5,6]] แล้วแสดงขนาด (shape)

# %%
# ✍️ เขียนโค้ดข้อ 13 ที่นี่

# %% [markdown]
# **ข้อ 14.** เขียนโปรแกรมสร้างอาร์เรย์ [1,2,3,4,5] แล้วแสดงจำนวนสมาชิกด้วย size

# %%
# ✍️ เขียนโค้ดข้อ 14 ที่นี่

# %% [markdown]
# **ข้อ 15.** เขียนโปรแกรมสร้างอาร์เรย์ [10,20,30] กับ [1,2,3] แล้วแสดงผลบวกทีละสมาชิก

# %%
# ✍️ เขียนโค้ดข้อ 15 ที่นี่

# %% [markdown]
# **ข้อ 16.** เขียนโปรแกรมสร้างอาร์เรย์ [2,4,6,8] แล้วแสดงส่วนเบี่ยงเบนมาตรฐานด้วย std()

# %%
# ✍️ เขียนโค้ดข้อ 16 ที่นี่

# %% [markdown]
# **ข้อ 17.** เขียนโปรแกรมสร้างเมทริกซ์ [[1,2],[3,4]] แล้วแสดงทรานสโพสด้วย .T

# %%
# ✍️ เขียนโค้ดข้อ 17 ที่นี่

# %% [markdown]
# **ข้อ 18.** เขียนโปรแกรมสร้างอาร์เรย์เลขคู่ 2 ถึง 20 ด้วย np.arange ที่มี step 2

# %%
# ✍️ เขียนโค้ดข้อ 18 ที่นี่

# %% [markdown]
# **ข้อ 19.** เขียนโปรแกรมสร้างอาร์เรย์ [5,10,15,20,25] แล้วแสดงสมาชิกตัวที่ 2 ถึง 4 ด้วย slicing

# %%
# ✍️ เขียนโค้ดข้อ 19 ที่นี่

# %% [markdown]
# **ข้อ 20.** เขียนโปรแกรมสร้างเมทริกซ์ [[1,2,3],[4,5,6]] แล้วแสดงสมาชิกแถว 1 หลัก 2

# %%
# ✍️ เขียนโค้ดข้อ 20 ที่นี่

# %% [markdown]
# ---
# ## ระดับที่ 2 — ปานกลาง (Intermediate)
# _ประยุกต์ความรู้แก้โจทย์ที่ซับซ้อนขึ้นและผสมหลายแนวคิด_

# %% [markdown]
# **ข้อ 21.** เขียนโปรแกรมสร้างอาร์เรย์เลข 1 ถึง 10 แล้วแสดงผลรวม ค่าเฉลี่ย และกำลังสองของทุกสมาชิก

# %%
# ✍️ เขียนโค้ดข้อ 21 ที่นี่

# %% [markdown]
# **ข้อ 22.** เขียนโปรแกรมสร้างอาร์เรย์สองชุด [1,2,3,4] และ [5,6,7,8] แล้วแสดงผลบวก ผลต่าง และผลคูณทีละสมาชิก

# %%
# ✍️ เขียนโค้ดข้อ 22 ที่นี่

# %% [markdown]
# **ข้อ 23.** เขียนโปรแกรมสร้างเมทริกซ์ 3×3 ด้วยเลข 1 ถึง 9 แล้วแสดงผลรวมของสมาชิกทั้งหมด

# %%
# ✍️ เขียนโค้ดข้อ 23 ที่นี่

# %% [markdown]
# **ข้อ 24.** เขียนโปรแกรมหาผลคูณเมทริกซ์ของ [[1,2],[3,4]] กับ [[5,6],[7,8]] ด้วย @

# %%
# ✍️ เขียนโค้ดข้อ 24 ที่นี่

# %% [markdown]
# **ข้อ 25.** เขียนโปรแกรมหาค่าเฉลี่ยและส่วนเบี่ยงเบนมาตรฐานของอาร์เรย์ [4,8,15,16,23,42] ทศนิยม 4 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 25 ที่นี่

# %% [markdown]
# **ข้อ 26.** เขียนโปรแกรมสร้างอาร์เรย์ 100 ค่าในช่วง 0 ถึง 2π แล้วคำนวณค่า sin ของแต่ละค่า แสดงค่ามากสุด

# %%
# ✍️ เขียนโค้ดข้อ 26 ที่นี่

# %% [markdown]
# **ข้อ 27.** เขียนโปรแกรมหาผลรวมของสมาชิกที่เป็นเลขคู่ในอาร์เรย์ [1,2,3,4,5,6,7,8] โดยใช้เงื่อนไขแบบ boolean indexing

# %%
# ✍️ เขียนโค้ดข้อ 27 ที่นี่

# %% [markdown]
# **ข้อ 28.** เขียนโปรแกรมสร้างเมทริกซ์ [[1,2],[3,4]] แล้วแสดงผลบวกและผลคูณทีละสมาชิกกับ [[5,6],[7,8]]

# %%
# ✍️ เขียนโค้ดข้อ 28 ที่นี่

# %% [markdown]
# **ข้อ 29.** เขียนโปรแกรมหาสมาชิกที่มากกว่าค่าเฉลี่ยในอาร์เรย์ [10,20,30,40,50]

# %%
# ✍️ เขียนโค้ดข้อ 29 ที่นี่

# %% [markdown]
# **ข้อ 30.** เขียนโปรแกรมสร้างอาร์เรย์ [3,1,4,1,5,9,2,6] แล้วเรียงจากน้อยไปมากด้วย np.sort

# %%
# ✍️ เขียนโค้ดข้อ 30 ที่นี่

# %% [markdown]
# **ข้อ 31.** เขียนโปรแกรมหาผลคูณจุด (dot product) ของเวกเตอร์ [1,2,3] กับ [4,5,6] ด้วย np.dot

# %%
# ✍️ เขียนโค้ดข้อ 31 ที่นี่

# %% [markdown]
# **ข้อ 32.** เขียนโปรแกรมสร้างเมทริกซ์เอกลักษณ์ขนาด 3×3 ด้วย np.eye

# %%
# ✍️ เขียนโค้ดข้อ 32 ที่นี่

# %% [markdown]
# **ข้อ 33.** เขียนโปรแกรมหาค่ามากสุด น้อยสุด และตำแหน่ง (argmax) ของอาร์เรย์ [3,7,2,9,4]

# %%
# ✍️ เขียนโค้ดข้อ 33 ที่นี่

# %% [markdown]
# **ข้อ 34.** เขียนโปรแกรมแปลงอุณหภูมิเซลเซียสในอาร์เรย์ [0,25,50,100] เป็นฟาเรนไฮต์ทั้งหมดในคราวเดียว

# %%
# ✍️ เขียนโค้ดข้อ 34 ที่นี่

# %% [markdown]
# **ข้อ 35.** เขียนโปรแกรมสร้างอาร์เรย์ [1,2,3,4,5] แล้วหาผลรวมสะสมด้วย np.cumsum

# %%
# ✍️ เขียนโค้ดข้อ 35 ที่นี่

# %% [markdown]
# **ข้อ 36.** เขียนโปรแกรมหาค่ามัธยฐานของอาร์เรย์ [7,1,5,3,9] ด้วย np.median

# %%
# ✍️ เขียนโค้ดข้อ 36 ที่นี่

# %% [markdown]
# **ข้อ 37.** เขียนโปรแกรมหาดีเทอร์มิแนนต์ของเมทริกซ์ [[2,1],[1,3]] ด้วย np.linalg.det

# %%
# ✍️ เขียนโค้ดข้อ 37 ที่นี่

# %% [markdown]
# **ข้อ 38.** เขียนโปรแกรมสร้างอาร์เรย์ [1,2,3,4,5,6] แล้วเปลี่ยนรูปร่างเป็นเมทริกซ์ 2×3 ด้วย reshape

# %%
# ✍️ เขียนโค้ดข้อ 38 ที่นี่

# %% [markdown]
# **ข้อ 39.** เขียนโปรแกรมหาผลรวมของแต่ละหลัก (column) ในเมทริกซ์ [[1,2,3],[4,5,6]] ด้วย axis=0

# %%
# ✍️ เขียนโค้ดข้อ 39 ที่นี่

# %% [markdown]
# **ข้อ 40.** เขียนโปรแกรมคำนวณค่า e ยกกำลังของอาร์เรย์ [0,1,2] ด้วย np.exp

# %%
# ✍️ เขียนโค้ดข้อ 40 ที่นี่

# %% [markdown]
# ---
# ## ระดับที่ 3 — ท้าทาย (Challenge)
# _โจทย์ประยุกต์เชิงคณิตศาสตร์และตรรกะที่ต้องคิดวิเคราะห์_

# %% [markdown]
# **ข้อ 41.** เขียนโปรแกรมแก้ระบบสมการเชิงเส้น 2x+y=11 และ x+3y=18 ด้วย np.linalg.solve

# %%
# ✍️ เขียนโค้ดข้อ 41 ที่นี่

# %% [markdown]
# **ข้อ 42.** เขียนโปรแกรมหาเมทริกซ์ผกผันของ [[2,1],[1,3]] ด้วย np.linalg.inv

# %%
# ✍️ เขียนโค้ดข้อ 42 ที่นี่

# %% [markdown]
# **ข้อ 43.** เขียนโปรแกรมแก้ระบบสมการ 3x+2y=12 และ x−y=1 แล้วแสดงค่า x และ y ทศนิยม 2 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 43 ที่นี่

# %% [markdown]
# **ข้อ 44.** เขียนโปรแกรมคำนวณนอร์ม (ความยาว) ของเวกเตอร์ [3,4] ด้วย np.linalg.norm

# %%
# ✍️ เขียนโค้ดข้อ 44 ที่นี่

# %% [markdown]
# **ข้อ 45.** เขียนโปรแกรมหาค่าเฉลี่ยของแต่ละแถวในเมทริกซ์ [[1,2,3],[4,5,6],[7,8,9]] ด้วย axis=1

# %%
# ✍️ เขียนโค้ดข้อ 45 ที่นี่

# %% [markdown]
# **ข้อ 46.** เขียนโปรแกรมประมาณค่าปริพันธ์ของ sin(x) ในช่วง 0 ถึง π ด้วยผลรวมรีมันน์ (n=1000)

# %%
# ✍️ เขียนโค้ดข้อ 46 ที่นี่

# %% [markdown]
# **ข้อ 47.** เขียนโปรแกรมสร้างเมทริกซ์ 3×3 แล้วตรวจว่าผลคูณกับเมทริกซ์ผกผันได้เมทริกซ์เอกลักษณ์ (ปัดทศนิยม)

# %%
# ✍️ เขียนโค้ดข้อ 47 ที่นี่

# %% [markdown]
# **ข้อ 48.** เขียนโปรแกรมคำนวณระยะทางแบบยุคลิดระหว่างเวกเตอร์ [1,2,3] กับ [4,6,8] ด้วย NumPy

# %%
# ✍️ เขียนโค้ดข้อ 48 ที่นี่

# %% [markdown]
# **ข้อ 49.** เขียนโปรแกรมหาค่าเฉลี่ยถ่วงน้ำหนักของคะแนน [80,90,70] ด้วยน้ำหนัก [0.3,0.5,0.2] โดยใช้ผลคูณจุด

# %%
# ✍️ เขียนโค้ดข้อ 49 ที่นี่

# %% [markdown]
# **ข้อ 50.** เขียนโปรแกรมปรับข้อมูลให้เป็นมาตรฐาน (standardize): (x−mean)/std ของอาร์เรย์ [10,20,30,40,50] ทศนิยม 2 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 50 ที่นี่
