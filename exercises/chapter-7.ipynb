# %% [markdown]
# # 040223101 การเขียนโปรแกรมคอมพิวเตอร์สำหรับคณิตศาสตร์ 1
# ## (Computer Programming for Mathematics 1)
#
# # แบบฝึกหัด บทที่ 7: โครงสร้างการทำซ้ำแบบมีเงื่อนไข (While Loops)
# ### While Loops
#
# **ผู้สอน:** รศ.ดร.อนุชิต จิตพัฒนกุล
# ภาควิชาคณิตศาสตร์ คณะวิทยาศาสตร์ประยุกต์  มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าพระนครเหนือ
#
# ---
#
# ### 📝 คำชี้แจง
# - ให้นักศึกษาเขียนโปรแกรมภาษา Python แก้โจทย์แต่ละข้อในเซลล์โค้ดที่เว้นว่างไว้ใต้โจทย์
# - กดปุ่ม **▶ Run** (หรือ Shift+Enter) เพื่อรันโค้ดและตรวจผลลัพธ์
# - โจทย์แบ่งเป็น 3 ระดับจากง่ายไปยาก ควรทำไล่ตามลำดับ
# - เขียนชื่อ-รหัสนักศึกษาของคุณในเซลล์ด้านล่างก่อนเริ่มทำ

# %%
# ✏️ กรอกข้อมูลของคุณ
student_name = ""   # ชื่อ-นามสกุล
student_id = ""     # รหัสนักศึกษา
print("ผู้ทำแบบฝึกหัด:", student_name, student_id)

# %% [markdown]
# ---
# ## ระดับที่ 1 — พื้นฐาน (Basic)
# _ฝึกใช้คำสั่งและไวยากรณ์พื้นฐานของบทนี้ให้คล่อง_

# %% [markdown]
# **ข้อ 1.** เขียนโปรแกรมแสดงเลข 1 ถึง 5 ด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 1 ที่นี่

# %% [markdown]
# **ข้อ 2.** เขียนโปรแกรมแสดงเลข 10 นับถอยหลังถึง 1 ด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 2 ที่นี่

# %% [markdown]
# **ข้อ 3.** เขียนโปรแกรมหาผลรวมของเลข 1 ถึง 100 ด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 3 ที่นี่

# %% [markdown]
# **ข้อ 4.** เขียนโปรแกรมแสดงเลขคู่ตั้งแต่ 2 ถึง 20 ด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 4 ที่นี่

# %% [markdown]
# **ข้อ 5.** เขียนโปรแกรมแสดง Hello จำนวน 5 ครั้งด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 5 ที่นี่

# %% [markdown]
# **ข้อ 6.** เขียนโปรแกรมหาผลคูณของเลข 1 ถึง 5 ด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 6 ที่นี่

# %% [markdown]
# **ข้อ 7.** เขียนโปรแกรมแสดงเลข 5, 10, 15, ..., 50 ด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 7 ที่นี่

# %% [markdown]
# **ข้อ 8.** เขียนโปรแกรมรับเลขจำนวนเต็มบวก n แล้วแสดงเลข 1 ถึง n ด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 8 ที่นี่

# %% [markdown]
# **ข้อ 9.** เขียนโปรแกรมนับจำนวนเลขที่หารด้วย 3 ลงตัวในช่วง 1 ถึง 30 ด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 9 ที่นี่

# %% [markdown]
# **ข้อ 10.** เขียนโปรแกรมแสดงกำลังของ 2 (1, 2, 4, 8, ...) ที่ไม่เกิน 100

# %%
# ✍️ เขียนโค้ดข้อ 10 ที่นี่

# %% [markdown]
# **ข้อ 11.** เขียนโปรแกรมหาผลรวมของเลขคี่ตั้งแต่ 1 ถึง 99 ด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 11 ที่นี่

# %% [markdown]
# **ข้อ 12.** เขียนโปรแกรมแสดงเลข 0 ถึง 9 บนบรรทัดเดียวด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 12 ที่นี่

# %% [markdown]
# **ข้อ 13.** เขียนโปรแกรมรับ n แล้วหาผลรวม 1 ถึง n ด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 13 ที่นี่

# %% [markdown]
# **ข้อ 14.** เขียนโปรแกรมแสดงตัวเลข 100, 90, 80, ..., 10 ด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 14 ที่นี่

# %% [markdown]
# **ข้อ 15.** เขียนโปรแกรมนับจำนวนรอบที่ต้องบวก 7 เข้าไปจนเกิน 50 เริ่มจาก 0

# %%
# ✍️ เขียนโค้ดข้อ 15 ที่นี่

# %% [markdown]
# **ข้อ 16.** เขียนโปรแกรมแสดงกำลังสองของเลข 1 ถึง 10 ด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 16 ที่นี่

# %% [markdown]
# **ข้อ 17.** เขียนโปรแกรมหาผลรวมของเลข 2, 4, 6, ..., 50 ด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 17 ที่นี่

# %% [markdown]
# **ข้อ 18.** เขียนโปรแกรมแสดงดาวเพิ่มทีละดวง 5 แถว (1 ถึง 5 ดวง) ด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 18 ที่นี่

# %% [markdown]
# **ข้อ 19.** เขียนโปรแกรมรับ n แล้วแสดงสูตรคูณแม่ n ด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 19 ที่นี่

# %% [markdown]
# **ข้อ 20.** เขียนโปรแกรมหาผลรวมของเลข 1 ถึง 50 แล้วแสดงเมื่อลูปจบ

# %%
# ✍️ เขียนโค้ดข้อ 20 ที่นี่

# %% [markdown]
# ---
# ## ระดับที่ 2 — ปานกลาง (Intermediate)
# _ประยุกต์ความรู้แก้โจทย์ที่ซับซ้อนขึ้นและผสมหลายแนวคิด_

# %% [markdown]
# **ข้อ 21.** เขียนโปรแกรมรับคะแนน (0-100) วนถามใหม่จนกว่าจะใส่ค่าที่ถูกต้อง

# %%
# ✍️ เขียนโค้ดข้อ 21 ที่นี่

# %% [markdown]
# **ข้อ 22.** เขียนโปรแกรมรับเลขไปเรื่อย ๆ จนกว่าจะใส่ 0 แล้วแสดงผลรวม

# %%
# ✍️ เขียนโค้ดข้อ 22 ที่นี่

# %% [markdown]
# **ข้อ 23.** เขียนโปรแกรมนับจำนวนหลักของจำนวนเต็มบวกที่รับเข้ามา

# %%
# ✍️ เขียนโค้ดข้อ 23 ที่นี่

# %% [markdown]
# **ข้อ 24.** เขียนโปรแกรมหาผลรวมของหลักทุกหลักของจำนวนที่รับเข้ามา

# %%
# ✍️ เขียนโค้ดข้อ 24 ที่นี่

# %% [markdown]
# **ข้อ 25.** เขียนโปรแกรมหาผลรวมของเลข 1, 2, 3, ... จนกว่าผลรวมจะเกิน 1000 แล้วแสดงว่าใช้เลขถึงตัวใด

# %%
# ✍️ เขียนโค้ดข้อ 25 ที่นี่

# %% [markdown]
# **ข้อ 26.** เขียนโปรแกรมกลับเลข เช่น 1234 เป็น 4321 ด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 26 ที่นี่

# %% [markdown]
# **ข้อ 27.** เขียนโปรแกรมหาจำนวนเต็มบวกน้อยที่สุดที่กำลังสองเกิน 200 ด้วย while และ break

# %%
# ✍️ เขียนโค้ดข้อ 27 ที่นี่

# %% [markdown]
# **ข้อ 28.** เขียนโปรแกรมแสดงเฉพาะเลขคี่ในช่วง 1 ถึง 20 ด้วย while และ continue

# %%
# ✍️ เขียนโค้ดข้อ 28 ที่นี่

# %% [markdown]
# **ข้อ 29.** เขียนโปรแกรมหารากที่สองของ S ที่รับเข้ามาด้วยวิธีของนิวตัน ทศนิยม 4 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 29 ที่นี่

# %% [markdown]
# **ข้อ 30.** เขียนโปรแกรมตรวจว่าจำนวนที่รับเข้ามาเป็นจำนวนเฉพาะหรือไม่ ด้วย while

# %%
# ✍️ เขียนโค้ดข้อ 30 ที่นี่

# %% [markdown]
# **ข้อ 31.** เขียนโปรแกรมหา ห.ร.ม. ของเลขสองจำนวนด้วยอัลกอริทึมยุคลิด (while)

# %%
# ✍️ เขียนโค้ดข้อ 31 ที่นี่

# %% [markdown]
# **ข้อ 32.** เขียนโปรแกรมรับเลขแล้วนับจำนวนครั้งที่หารด้วย 2 ได้จนเหลือเลขคี่

# %%
# ✍️ เขียนโค้ดข้อ 32 ที่นี่

# %% [markdown]
# **ข้อ 33.** เขียนโปรแกรมแสดงลำดับฟีโบนัชชีที่ไม่เกิน 100 ด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 33 ที่นี่

# %% [markdown]
# **ข้อ 34.** เขียนโปรแกรมรับเลขจนกว่าจะใส่เลขลบ แล้วแสดงว่ารับเลขไปกี่ตัว (ไม่นับเลขลบ)

# %%
# ✍️ เขียนโค้ดข้อ 34 ที่นี่

# %% [markdown]
# **ข้อ 35.** เขียนโปรแกรมหาผลรวมของอนุกรม 1/2 + 1/4 + 1/8 + ... จนพจน์น้อยกว่า 0.001

# %%
# ✍️ เขียนโค้ดข้อ 35 ที่นี่

# %% [markdown]
# **ข้อ 36.** เขียนโปรแกรมจำลองเงินฝากที่โตปีละ 5% เริ่ม 1000 บาท หาว่ากี่ปีจึงเกิน 2000 บาท

# %%
# ✍️ เขียนโค้ดข้อ 36 ที่นี่

# %% [markdown]
# **ข้อ 37.** เขียนโปรแกรมรับรหัสผ่านวนถามจนกว่าจะตรงกับ 1234 (จำกัดเปรียบเทียบกับสตริง)

# %%
# ✍️ เขียนโค้ดข้อ 37 ที่นี่

# %% [markdown]
# **ข้อ 38.** เขียนโปรแกรมหาผลคูณสะสมของเลข 1, 2, 3, ... จนกว่าผลคูณจะเกิน 1000

# %%
# ✍️ เขียนโค้ดข้อ 38 ที่นี่

# %% [markdown]
# **ข้อ 39.** เขียนโปรแกรมนับจำนวนเลข 0 ในจำนวนเต็มที่รับเข้ามา

# %%
# ✍️ เขียนโค้ดข้อ 39 ที่นี่

# %% [markdown]
# **ข้อ 40.** เขียนโปรแกรมรับเลขแล้วหาว่าเป็นเลขกี่หลักและหลักแรก (หลักซ้ายสุด) คือเลขใด

# %%
# ✍️ เขียนโค้ดข้อ 40 ที่นี่

# %% [markdown]
# ---
# ## ระดับที่ 3 — ท้าทาย (Challenge)
# _โจทย์ประยุกต์เชิงคณิตศาสตร์และตรรกะที่ต้องคิดวิเคราะห์_

# %% [markdown]
# **ข้อ 41.** เขียนโปรแกรมตรวจว่าจำนวนที่รับเข้ามาเป็นเลขพาลินโดรมหรือไม่ (กลับแล้วเท่าเดิม)

# %%
# ✍️ เขียนโค้ดข้อ 41 ที่นี่

# %% [markdown]
# **ข้อ 42.** เขียนโปรแกรมหาผลบวกของหลักซ้ำจนเหลือหลักเดียว (digital root) ของจำนวนที่รับเข้ามา

# %%
# ✍️ เขียนโค้ดข้อ 42 ที่นี่

# %% [markdown]
# **ข้อ 43.** เขียนโปรแกรมจำลองการเดาเลข: ตั้งเลขลับ 42 รับการเดาจนกว่าจะถูก พร้อมบอกสูงไป/ต่ำไป

# %%
# ✍️ เขียนโค้ดข้อ 43 ที่นี่

# %% [markdown]
# **ข้อ 44.** เขียนโปรแกรมแปลงเลขฐานสิบเป็นเลขฐานสองด้วยลูป while แล้วแสดงผล

# %%
# ✍️ เขียนโค้ดข้อ 44 ที่นี่

# %% [markdown]
# **ข้อ 45.** เขียนโปรแกรมหาจำนวนเฉพาะ 10 ตัวแรกด้วยลูป while

# %%
# ✍️ เขียนโค้ดข้อ 45 ที่นี่

# %% [markdown]
# **ข้อ 46.** เขียนโปรแกรมประมาณค่า π ด้วยอนุกรมไลบ์นิซจนพจน์น้อยกว่า 0.0001 ทศนิยม 4 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 46 ที่นี่

# %% [markdown]
# **ข้อ 47.** เขียนโปรแกรมหาผลรวมของตัวเลขที่ผู้ใช้ป้อนจนกว่าจะป้อนคำว่า end (ใช้ break)

# %%
# ✍️ เขียนโค้ดข้อ 47 ที่นี่

# %% [markdown]
# **ข้อ 48.** เขียนโปรแกรมหาตัวเลขที่น้อยที่สุดที่หารด้วย 1 ถึง 5 ลงตัวทั้งหมด (ค.ร.น.)

# %%
# ✍️ เขียนโค้ดข้อ 48 ที่นี่

# %% [markdown]
# **ข้อ 49.** เขียนโปรแกรมจำลองดอกเบี้ยทบต้น: เงินต้นและอัตราที่รับเข้ามา หาว่ากี่ปีจึงเป็นสองเท่า

# %%
# ✍️ เขียนโค้ดข้อ 49 ที่นี่

# %% [markdown]
# **ข้อ 50.** เขียนโปรแกรมหาเลขอาร์มสตรองสามหลัก (ผลรวมกำลังสามของแต่ละหลักเท่ากับตัวเลข) ในช่วง 100-999

# %%
# ✍️ เขียนโค้ดข้อ 50 ที่นี่
