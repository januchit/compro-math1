# %% [markdown]
# # 040223101 การเขียนโปรแกรมคอมพิวเตอร์สำหรับคณิตศาสตร์ 1
# ## (Computer Programming for Mathematics 1)
#
# # แบบฝึกหัด บทที่ 9: ฟังก์ชัน
# ### Functions
#
# **ผู้สอน:** รศ.ดร.อนุชิต จิตพัฒนกุล
# ภาควิชาคณิตศาสตร์ คณะวิทยาศาสตร์ประยุกต์  มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าพระนครเหนือ
#
# ---
#
# ### 📝 คำชี้แจง
# - ให้นักศึกษาเขียนโปรแกรมภาษา Python แก้โจทย์แต่ละข้อในเซลล์โค้ดที่เว้นว่างไว้ใต้โจทย์
# - กดปุ่ม **▶ Run** (หรือ Shift+Enter) เพื่อรันโค้ดและตรวจผลลัพธ์
# - โจทย์แบ่งเป็น 3 ระดับจากง่ายไปยาก ควรทำไล่ตามลำดับ
# - เขียนชื่อ-รหัสนักศึกษาของคุณในเซลล์ด้านล่างก่อนเริ่มทำ

# %%
# ✏️ กรอกข้อมูลของคุณ
student_name = ""   # ชื่อ-นามสกุล
student_id = ""     # รหัสนักศึกษา
print("ผู้ทำแบบฝึกหัด:", student_name, student_id)

# %% [markdown]
# ---
# ## ระดับที่ 1 — พื้นฐาน (Basic)
# _ฝึกใช้คำสั่งและไวยากรณ์พื้นฐานของบทนี้ให้คล่อง_

# %% [markdown]
# **ข้อ 1.** เขียนฟังก์ชัน greet() ที่แสดงข้อความ สวัสดี แล้วเรียกใช้

# %%
# ✍️ เขียนโค้ดข้อ 1 ที่นี่

# %% [markdown]
# **ข้อ 2.** เขียนฟังก์ชัน square(x) ที่คืนค่ากำลังสองของ x แล้วแสดง square(5)

# %%
# ✍️ เขียนโค้ดข้อ 2 ที่นี่

# %% [markdown]
# **ข้อ 3.** เขียนฟังก์ชัน add(a, b) ที่คืนผลบวกของ a และ b

# %%
# ✍️ เขียนโค้ดข้อ 3 ที่นี่

# %% [markdown]
# **ข้อ 4.** เขียนฟังก์ชัน greet_name(name) ที่แสดง สวัสดีคุณ ตามด้วยชื่อ

# %%
# ✍️ เขียนโค้ดข้อ 4 ที่นี่

# %% [markdown]
# **ข้อ 5.** เขียนฟังก์ชัน cube(x) ที่คืนค่ากำลังสามของ x

# %%
# ✍️ เขียนโค้ดข้อ 5 ที่นี่

# %% [markdown]
# **ข้อ 6.** เขียนฟังก์ชัน triangle_area(b, h) ที่คืนพื้นที่สามเหลี่ยม

# %%
# ✍️ เขียนโค้ดข้อ 6 ที่นี่

# %% [markdown]
# **ข้อ 7.** เขียนฟังก์ชัน is_even(n) ที่คืน True ถ้า n เป็นเลขคู่

# %%
# ✍️ เขียนโค้ดข้อ 7 ที่นี่

# %% [markdown]
# **ข้อ 8.** เขียนฟังก์ชัน rectangle_area(w, l) ที่คืนพื้นที่สี่เหลี่ยมผืนผ้า

# %%
# ✍️ เขียนโค้ดข้อ 8 ที่นี่

# %% [markdown]
# **ข้อ 9.** เขียนฟังก์ชัน maximum(a, b) ที่คืนค่าที่มากกว่าระหว่าง a กับ b

# %%
# ✍️ เขียนโค้ดข้อ 9 ที่นี่

# %% [markdown]
# **ข้อ 10.** เขียนฟังก์ชัน absolute(x) ที่คืนค่าสัมบูรณ์ของ x (ไม่ใช้ abs)

# %%
# ✍️ เขียนโค้ดข้อ 10 ที่นี่

# %% [markdown]
# **ข้อ 11.** เขียนฟังก์ชัน to_fahrenheit(c) ที่แปลงเซลเซียสเป็นฟาเรนไฮต์

# %%
# ✍️ เขียนโค้ดข้อ 11 ที่นี่

# %% [markdown]
# **ข้อ 12.** เขียนฟังก์ชัน circle_area(r) ที่คืนพื้นที่วงกลม (ใช้ 3.14159)

# %%
# ✍️ เขียนโค้ดข้อ 12 ที่นี่

# %% [markdown]
# **ข้อ 13.** เขียนฟังก์ชัน double(x) ที่คืนค่าสองเท่าของ x

# %%
# ✍️ เขียนโค้ดข้อ 13 ที่นี่

# %% [markdown]
# **ข้อ 14.** เขียนฟังก์ชัน average3(a, b, c) ที่คืนค่าเฉลี่ยของสามจำนวน

# %%
# ✍️ เขียนโค้ดข้อ 14 ที่นี่

# %% [markdown]
# **ข้อ 15.** เขียนฟังก์ชัน greet_times(n) ที่แสดง Hello จำนวน n ครั้ง

# %%
# ✍️ เขียนโค้ดข้อ 15 ที่นี่

# %% [markdown]
# **ข้อ 16.** เขียนฟังก์ชัน is_positive(n) ที่คืน True ถ้า n มากกว่า 0

# %%
# ✍️ เขียนโค้ดข้อ 16 ที่นี่

# %% [markdown]
# **ข้อ 17.** เขียนฟังก์ชัน power(base, exp) ที่คืน base ยกกำลัง exp

# %%
# ✍️ เขียนโค้ดข้อ 17 ที่นี่

# %% [markdown]
# **ข้อ 18.** เขียนฟังก์ชัน km_to_m(km) ที่แปลงกิโลเมตรเป็นเมตร

# %%
# ✍️ เขียนโค้ดข้อ 18 ที่นี่

# %% [markdown]
# **ข้อ 19.** เขียนฟังก์ชัน subtract(a, b) ที่คืนผลลบ a ลบ b แล้วเรียกใช้สองครั้งด้วยค่าต่างกัน

# %%
# ✍️ เขียนโค้ดข้อ 19 ที่นี่

# %% [markdown]
# **ข้อ 20.** เขียนฟังก์ชัน greet_default(name) ที่มีค่าปริยายของ name เป็น Guest

# %%
# ✍️ เขียนโค้ดข้อ 20 ที่นี่

# %% [markdown]
# ---
# ## ระดับที่ 2 — ปานกลาง (Intermediate)
# _ประยุกต์ความรู้แก้โจทย์ที่ซับซ้อนขึ้นและผสมหลายแนวคิด_

# %% [markdown]
# **ข้อ 21.** เขียนฟังก์ชัน factorial(n) ที่คืนค่าแฟกทอเรียลของ n ด้วยลูป

# %%
# ✍️ เขียนโค้ดข้อ 21 ที่นี่

# %% [markdown]
# **ข้อ 22.** เขียนฟังก์ชัน circle(r) ที่คืนทั้งเส้นรอบวงและพื้นที่ของวงกลม

# %%
# ✍️ เขียนโค้ดข้อ 22 ที่นี่

# %% [markdown]
# **ข้อ 23.** เขียนฟังก์ชัน maximum3(a, b, c) ที่คืนค่าที่มากที่สุดในสามจำนวน

# %%
# ✍️ เขียนโค้ดข้อ 23 ที่นี่

# %% [markdown]
# **ข้อ 24.** เขียนฟังก์ชัน is_prime(n) ที่คืน True ถ้า n เป็นจำนวนเฉพาะ

# %%
# ✍️ เขียนโค้ดข้อ 24 ที่นี่

# %% [markdown]
# **ข้อ 25.** เขียนฟังก์ชัน sum_list(numbers) ที่คืนผลรวมของสมาชิกในลิสต์

# %%
# ✍️ เขียนโค้ดข้อ 25 ที่นี่

# %% [markdown]
# **ข้อ 26.** เขียนฟังก์ชัน count_even(numbers) ที่คืนจำนวนเลขคู่ในลิสต์

# %%
# ✍️ เขียนโค้ดข้อ 26 ที่นี่

# %% [markdown]
# **ข้อ 27.** เขียนฟังก์ชัน stat(numbers) ที่คืนค่าต่ำสุด สูงสุด และเฉลี่ยของลิสต์

# %%
# ✍️ เขียนโค้ดข้อ 27 ที่นี่

# %% [markdown]
# **ข้อ 28.** เขียนฟังก์ชัน gcd(a, b) ที่คืน ห.ร.ม. ด้วยอัลกอริทึมยุคลิด

# %%
# ✍️ เขียนโค้ดข้อ 28 ที่นี่

# %% [markdown]
# **ข้อ 29.** เขียนฟังก์ชัน reverse_number(n) ที่คืนเลขที่กลับหลักแล้ว

# %%
# ✍️ เขียนโค้ดข้อ 29 ที่นี่

# %% [markdown]
# **ข้อ 30.** เขียนฟังก์ชัน digit_sum(n) ที่คืนผลรวมของหลักทุกหลัก

# %%
# ✍️ เขียนโค้ดข้อ 30 ที่นี่

# %% [markdown]
# **ข้อ 31.** เขียนฟังก์ชัน power_loop(base, exp) ที่คืน base ยกกำลัง exp ด้วยลูป (ไม่ใช้ **)

# %%
# ✍️ เขียนโค้ดข้อ 31 ที่นี่

# %% [markdown]
# **ข้อ 32.** เขียนฟังก์ชัน bmi(weight, height) ที่คืนค่า BMI

# %%
# ✍️ เขียนโค้ดข้อ 32 ที่นี่

# %% [markdown]
# **ข้อ 33.** เขียนฟังก์ชัน is_leap(year) ที่คืน True ถ้าเป็นปีอธิกสุรทิน

# %%
# ✍️ เขียนโค้ดข้อ 33 ที่นี่

# %% [markdown]
# **ข้อ 34.** เขียนฟังก์ชัน count_vowels(text) ที่นับจำนวนสระภาษาอังกฤษ

# %%
# ✍️ เขียนโค้ดข้อ 34 ที่นี่

# %% [markdown]
# **ข้อ 35.** เขียนฟังก์ชัน max_in_list(numbers) ที่คืนค่ามากที่สุด (ไม่ใช้ max)

# %%
# ✍️ เขียนโค้ดข้อ 35 ที่นี่

# %% [markdown]
# **ข้อ 36.** เขียนฟังก์ชัน sum_to(n) ที่คืนผลรวม 1 ถึง n และเรียกใช้กับ n=100

# %%
# ✍️ เขียนโค้ดข้อ 36 ที่นี่

# %% [markdown]
# **ข้อ 37.** เขียนฟังก์ชัน celsius_to_kelvin(c) ที่มีค่าปริยาย c=0 แปลงเป็นเคลวิน (C+273.15)

# %%
# ✍️ เขียนโค้ดข้อ 37 ที่นี่

# %% [markdown]
# **ข้อ 38.** เขียนฟังก์ชัน count_divisors(n) ที่คืนจำนวนตัวหารของ n

# %%
# ✍️ เขียนโค้ดข้อ 38 ที่นี่

# %% [markdown]
# **ข้อ 39.** เขียนฟังก์ชัน average(numbers) ที่คืนค่าเฉลี่ยของลิสต์ และทดสอบกับลิสต์ว่างโดยคืน 0

# %%
# ✍️ เขียนโค้ดข้อ 39 ที่นี่

# %% [markdown]
# **ข้อ 40.** เขียนฟังก์ชัน hypotenuse(a, b) ที่คืนความยาวด้านตรงข้ามมุมฉาก

# %%
# ✍️ เขียนโค้ดข้อ 40 ที่นี่

# %% [markdown]
# ---
# ## ระดับที่ 3 — ท้าทาย (Challenge)
# _โจทย์ประยุกต์เชิงคณิตศาสตร์และตรรกะที่ต้องคิดวิเคราะห์_

# %% [markdown]
# **ข้อ 41.** เขียนฟังก์ชันเรียกซ้ำ factorial(n) ที่คืนค่าแฟกทอเรียลของ n

# %%
# ✍️ เขียนโค้ดข้อ 41 ที่นี่

# %% [markdown]
# **ข้อ 42.** เขียนฟังก์ชันเรียกซ้ำ fibonacci(n) ที่คืนพจน์ที่ n ของลำดับฟีโบนัชชี

# %%
# ✍️ เขียนโค้ดข้อ 42 ที่นี่

# %% [markdown]
# **ข้อ 43.** เขียนฟังก์ชันเรียกซ้ำ sum_to(n) ที่คืนผลรวม 1 ถึง n

# %%
# ✍️ เขียนโค้ดข้อ 43 ที่นี่

# %% [markdown]
# **ข้อ 44.** เขียนฟังก์ชันเรียกซ้ำ power(base, exp) ที่คืน base ยกกำลัง exp

# %%
# ✍️ เขียนโค้ดข้อ 44 ที่นี่

# %% [markdown]
# **ข้อ 45.** เขียนฟังก์ชันเรียกซ้ำ gcd(a, b) ด้วยอัลกอริทึมยุคลิด

# %%
# ✍️ เขียนโค้ดข้อ 45 ที่นี่

# %% [markdown]
# **ข้อ 46.** เขียนฟังก์ชัน is_prime(n) แล้วใช้พิมพ์จำนวนเฉพาะในช่วง 2 ถึง 50

# %%
# ✍️ เขียนโค้ดข้อ 46 ที่นี่

# %% [markdown]
# **ข้อ 47.** เขียนฟังก์ชัน combination(n, r) ที่คืนค่า C(n,r) = n!/(r!(n-r)!) โดยเรียกใช้ฟังก์ชัน factorial

# %%
# ✍️ เขียนโค้ดข้อ 47 ที่นี่

# %% [markdown]
# **ข้อ 48.** เขียนฟังก์ชันเรียกซ้ำ sum_digits(n) ที่คืนผลรวมของหลักทุกหลัก

# %%
# ✍️ เขียนโค้ดข้อ 48 ที่นี่

# %% [markdown]
# **ข้อ 49.** เขียนฟังก์ชัน count_primes(limit) ที่คืนจำนวนของจำนวนเฉพาะที่ไม่เกิน limit

# %%
# ✍️ เขียนโค้ดข้อ 49 ที่นี่

# %% [markdown]
# **ข้อ 50.** เขียนฟังก์ชัน apply_discount(price, percent=10) ที่คืนราคาหลังหักส่วนลด มีค่าปริยาย 10%

# %%
# ✍️ เขียนโค้ดข้อ 50 ที่นี่
