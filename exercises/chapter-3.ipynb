# %% [markdown]
# # 040223101 การเขียนโปรแกรมคอมพิวเตอร์สำหรับคณิตศาสตร์ 1
# ## (Computer Programming for Mathematics 1)
#
# # แบบฝึกหัด บทที่ 3: การใช้ไลบรารีสำเร็จรูป
# ### Libraries
#
# **ผู้สอน:** รศ.ดร.อนุชิต จิตพัฒนกุล
# ภาควิชาคณิตศาสตร์ คณะวิทยาศาสตร์ประยุกต์  มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าพระนครเหนือ
#
# ---
#
# ### 📝 คำชี้แจง
# - ให้นักศึกษาเขียนโปรแกรมภาษา Python แก้โจทย์แต่ละข้อในเซลล์โค้ดที่เว้นว่างไว้ใต้โจทย์
# - กดปุ่ม **▶ Run** (หรือ Shift+Enter) เพื่อรันโค้ดและตรวจผลลัพธ์
# - โจทย์แบ่งเป็น 3 ระดับจากง่ายไปยาก ควรทำไล่ตามลำดับ
# - เขียนชื่อ-รหัสนักศึกษาของคุณในเซลล์ด้านล่างก่อนเริ่มทำ

# %%
# ✏️ กรอกข้อมูลของคุณ
student_name = ""   # ชื่อ-นามสกุล
student_id = ""     # รหัสนักศึกษา
print("ผู้ทำแบบฝึกหัด:", student_name, student_id)

# %% [markdown]
# ---
# ## ระดับที่ 1 — พื้นฐาน (Basic)
# _ฝึกใช้คำสั่งและไวยากรณ์พื้นฐานของบทนี้ให้คล่อง_

# %% [markdown]
# **ข้อ 1.** เขียนโปรแกรมนำเข้ามอดูล math แล้วแสดงค่ารากที่สองของ 64

# %%
# ✍️ เขียนโค้ดข้อ 1 ที่นี่

# %% [markdown]
# **ข้อ 2.** เขียนโปรแกรมแสดงค่าคงที่ pi จากมอดูล math

# %%
# ✍️ เขียนโค้ดข้อ 2 ที่นี่

# %% [markdown]
# **ข้อ 3.** เขียนโปรแกรมแสดงค่าคงที่ e จากมอดูล math

# %%
# ✍️ เขียนโค้ดข้อ 3 ที่นี่

# %% [markdown]
# **ข้อ 4.** เขียนโปรแกรมแสดงค่าแฟกทอเรียลของ 6 ด้วย math.factorial

# %%
# ✍️ เขียนโค้ดข้อ 4 ที่นี่

# %% [markdown]
# **ข้อ 5.** เขียนโปรแกรมแสดงค่าของ 2 ยกกำลัง 10 ด้วย math.pow

# %%
# ✍️ เขียนโค้ดข้อ 5 ที่นี่

# %% [markdown]
# **ข้อ 6.** เขียนโปรแกรมปัดเศษ 4.3 ขึ้นเป็นจำนวนเต็มด้วย math.ceil

# %%
# ✍️ เขียนโค้ดข้อ 6 ที่นี่

# %% [markdown]
# **ข้อ 7.** เขียนโปรแกรมปัดเศษ 4.8 ลงเป็นจำนวนเต็มด้วย math.floor

# %%
# ✍️ เขียนโค้ดข้อ 7 ที่นี่

# %% [markdown]
# **ข้อ 8.** เขียนโปรแกรมหา ห.ร.ม. ของ 24 และ 36 ด้วย math.gcd

# %%
# ✍️ เขียนโค้ดข้อ 8 ที่นี่

# %% [markdown]
# **ข้อ 9.** เขียนโปรแกรมนำเข้าเฉพาะ sqrt จากมอดูล math แล้วแสดงรากที่สองของ 49

# %%
# ✍️ เขียนโค้ดข้อ 9 ที่นี่

# %% [markdown]
# **ข้อ 10.** เขียนโปรแกรมนำเข้ามอดูล math เป็นชื่อย่อ m แล้วแสดงแฟกทอเรียลของ 5

# %%
# ✍️ เขียนโค้ดข้อ 10 ที่นี่

# %% [markdown]
# **ข้อ 11.** เขียนโปรแกรมนำเข้ามอดูล random แล้วแสดงจำนวนเต็มสุ่มในช่วง 1 ถึง 6

# %%
# ✍️ เขียนโค้ดข้อ 11 ที่นี่

# %% [markdown]
# **ข้อ 12.** เขียนโปรแกรมสุ่มเลือกผลไม้หนึ่งชนิดจาก apple, banana, cherry

# %%
# ✍️ เขียนโค้ดข้อ 12 ที่นี่

# %% [markdown]
# **ข้อ 13.** เขียนโปรแกรมแสดงเลขทศนิยมสุ่มในช่วง 0 ถึง 1 ด้วย random.random

# %%
# ✍️ เขียนโค้ดข้อ 13 ที่นี่

# %% [markdown]
# **ข้อ 14.** เขียนโปรแกรมแสดงค่าสัมบูรณ์ของ -15 ด้วย math.fabs

# %%
# ✍️ เขียนโค้ดข้อ 14 ที่นี่

# %% [markdown]
# **ข้อ 15.** เขียนโปรแกรมแสดงค่า log ฐานธรรมชาติของ e (ผลควรเป็น 1.0)

# %%
# ✍️ เขียนโค้ดข้อ 15 ที่นี่

# %% [markdown]
# **ข้อ 16.** เขียนโปรแกรมแสดงค่า log ฐาน 10 ของ 1000 ด้วย math.log10

# %%
# ✍️ เขียนโค้ดข้อ 16 ที่นี่

# %% [markdown]
# **ข้อ 17.** เขียนโปรแกรมแสดงค่า sin ของ 0 เรเดียน

# %%
# ✍️ เขียนโค้ดข้อ 17 ที่นี่

# %% [markdown]
# **ข้อ 18.** เขียนโปรแกรมแปลงมุม 180 องศาเป็นเรเดียนด้วย math.radians

# %%
# ✍️ เขียนโค้ดข้อ 18 ที่นี่

# %% [markdown]
# **ข้อ 19.** เขียนโปรแกรมแสดงรากที่สองของ 2 ทศนิยม 4 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 19 ที่นี่

# %% [markdown]
# **ข้อ 20.** เขียนโปรแกรมแสดงจำนวนเต็มสุ่ม 1 ถึง 100

# %%
# ✍️ เขียนโค้ดข้อ 20 ที่นี่

# %% [markdown]
# ---
# ## ระดับที่ 2 — ปานกลาง (Intermediate)
# _ประยุกต์ความรู้แก้โจทย์ที่ซับซ้อนขึ้นและผสมหลายแนวคิด_

# %% [markdown]
# **ข้อ 21.** เขียนโปรแกรมรับจำนวนเต็มบวก n แล้วแสดงแฟกทอเรียลของ n

# %%
# ✍️ เขียนโค้ดข้อ 21 ที่นี่

# %% [markdown]
# **ข้อ 22.** เขียนโปรแกรมรับด้านประกอบมุมฉากสองด้าน แล้วแสดงด้านตรงข้ามมุมฉากด้วย math.sqrt

# %%
# ✍️ เขียนโค้ดข้อ 22 ที่นี่

# %% [markdown]
# **ข้อ 23.** เขียนโปรแกรมรับเลขสองจำนวน แล้วแสดง ห.ร.ม. และ ค.ร.น. (a*b/ห.ร.ม.)

# %%
# ✍️ เขียนโค้ดข้อ 23 ที่นี่

# %% [markdown]
# **ข้อ 24.** เขียนโปรแกรมจำลองการทอยลูกเต๋าสองลูก แล้วแสดงแต้มแต่ละลูกและผลรวม

# %%
# ✍️ เขียนโค้ดข้อ 24 ที่นี่

# %% [markdown]
# **ข้อ 25.** เขียนโปรแกรมรับรัศมีทรงกลม แล้วคำนวณปริมาตร (4/3 × π × r³) ทศนิยม 2 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 25 ที่นี่

# %% [markdown]
# **ข้อ 26.** เขียนโปรแกรมรับมุมเป็นองศา แล้วแสดงค่า sin ของมุมนั้น (แปลงเป็นเรเดียนก่อน) ทศนิยม 4 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 26 ที่นี่

# %% [markdown]
# **ข้อ 27.** เขียนโปรแกรมรับมุม 30, 45, 60 องศาทีละค่า แล้วแสดงค่า cos (ตัวอย่างรับ 60)

# %%
# ✍️ เขียนโค้ดข้อ 27 ที่นี่

# %% [markdown]
# **ข้อ 28.** เขียนโปรแกรมสุ่มเลขล็อตเตอรี่ 6 หลัก (000000-999999) แสดงเป็นเลขจำนวนเต็ม

# %%
# ✍️ เขียนโค้ดข้อ 28 ที่นี่

# %% [markdown]
# **ข้อ 29.** เขียนโปรแกรมรับเลขทศนิยม แล้วแสดงทั้งค่าที่ปัดขึ้นและปัดลงเป็นจำนวนเต็ม

# %%
# ✍️ เขียนโค้ดข้อ 29 ที่นี่

# %% [markdown]
# **ข้อ 30.** เขียนโปรแกรมรับเลขจำนวนจริงบวก แล้วแสดง log ฐานธรรมชาติและ log ฐาน 10 ทศนิยม 4 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 30 ที่นี่

# %% [markdown]
# **ข้อ 31.** เขียนโปรแกรมจำลองการโยนเหรียญ แล้วแสดงผลเป็น หัว หรือ ก้อย

# %%
# ✍️ เขียนโค้ดข้อ 31 ที่นี่

# %% [markdown]
# **ข้อ 32.** เขียนโปรแกรมรับจำนวนเต็มบวก n แล้วแสดงค่ารากที่ n ของ 2 (2 ยกกำลัง 1/n)

# %%
# ✍️ เขียนโค้ดข้อ 32 ที่นี่

# %% [markdown]
# **ข้อ 33.** เขียนโปรแกรมสุ่มเลขทศนิยมในช่วง 10 ถึง 20 ด้วย random.uniform แสดงทศนิยม 2 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 33 ที่นี่

# %% [markdown]
# **ข้อ 34.** เขียนโปรแกรมรับเลขจำนวนเต็ม แล้วใช้ math.gcd ตรวจว่าเลขนั้นกับ 1 มี ห.ร.ม. เป็นเท่าใด

# %%
# ✍️ เขียนโค้ดข้อ 34 ที่นี่

# %% [markdown]
# **ข้อ 35.** เขียนโปรแกรมรับความยาวด้านสามเหลี่ยมด้านเท่า แล้วคำนวณพื้นที่ (√3/4 × ด้าน²) ทศนิยม 2 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 35 ที่นี่

# %% [markdown]
# **ข้อ 36.** เขียนโปรแกรมรับเลขจำนวนเต็ม n แล้วแสดงค่า 10 ยกกำลัง n ด้วย math.pow

# %%
# ✍️ เขียนโค้ดข้อ 36 ที่นี่

# %% [markdown]
# **ข้อ 37.** เขียนโปรแกรมแสดงค่า tan ของ 45 องศา (ควรใกล้ 1.0) ทศนิยม 4 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 37 ที่นี่

# %% [markdown]
# **ข้อ 38.** เขียนโปรแกรมสุ่มจำนวนเต็มสามตัวในช่วง 1-50 แล้วแสดงทั้งสามค่า

# %%
# ✍️ เขียนโค้ดข้อ 38 ที่นี่

# %% [markdown]
# **ข้อ 39.** เขียนโปรแกรมรับเลขจำนวนจริง แล้วแสดงค่า e ยกกำลังเลขนั้นด้วย math.exp ทศนิยม 4 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 39 ที่นี่

# %% [markdown]
# **ข้อ 40.** เขียนโปรแกรมรับจำนวนเต็มบวก n แล้วแสดงจำนวนหลักของ n! โดยใช้ความยาวของ str(แฟกทอเรียล)

# %%
# ✍️ เขียนโค้ดข้อ 40 ที่นี่

# %% [markdown]
# ---
# ## ระดับที่ 3 — ท้าทาย (Challenge)
# _โจทย์ประยุกต์เชิงคณิตศาสตร์และตรรกะที่ต้องคิดวิเคราะห์_

# %% [markdown]
# **ข้อ 41.** เขียนโปรแกรมรับสัมประสิทธิ์ a, b, c ของสมการกำลังสอง แล้วแสดงรากทั้งสอง (กรณีมีรากจริง)

# %%
# ✍️ เขียนโค้ดข้อ 41 ที่นี่

# %% [markdown]
# **ข้อ 42.** เขียนโปรแกรมคำนวณระยะทางระหว่างจุดสองจุดในระนาบด้วย math.dist (หรือ sqrt)

# %%
# ✍️ เขียนโค้ดข้อ 42 ที่นี่

# %% [markdown]
# **ข้อ 43.** เขียนโปรแกรมจำลองการทอยลูกเต๋าจนได้แต้ม 6 ครั้งแรก แสดงแต้มที่ทอยได้เพียงครั้งเดียว (สุ่มหนึ่งครั้ง)

# %%
# ✍️ เขียนโค้ดข้อ 43 ที่นี่

# %% [markdown]
# **ข้อ 44.** เขียนโปรแกรมรับมุม A และความยาวด้านตรงข้ามมุมฉาก แล้วคำนวณด้านประชิดมุม (hyp × cos A)

# %%
# ✍️ เขียนโค้ดข้อ 44 ที่นี่

# %% [markdown]
# **ข้อ 45.** เขียนโปรแกรมประมาณค่า e ด้วย math.exp(1) เทียบกับ math.e แสดงทั้งสองค่า

# %%
# ✍️ เขียนโค้ดข้อ 45 ที่นี่

# %% [markdown]
# **ข้อ 46.** เขียนโปรแกรมรับเลขจำนวนเต็มบวก n แล้วคำนวณค่าคอมบิเนชัน C(n,2) = n!/(2!(n-2)!)

# %%
# ✍️ เขียนโค้ดข้อ 46 ที่นี่

# %% [markdown]
# **ข้อ 47.** เขียนโปรแกรมรับความยาวด้านสามด้านของสามเหลี่ยม แล้วคำนวณพื้นที่ด้วยสูตรเฮรอน

# %%
# ✍️ เขียนโค้ดข้อ 47 ที่นี่

# %% [markdown]
# **ข้อ 48.** เขียนโปรแกรมจำลองสุ่มรหัส OTP 4 หลักโดยให้แต่ละหลักสุ่ม 0-9 แล้วแสดงเป็นเลขสี่หลัก (เติมศูนย์หน้า)

# %%
# ✍️ เขียนโค้ดข้อ 48 ที่นี่

# %% [markdown]
# **ข้อ 49.** เขียนโปรแกรมรับรัศมีและมุมศูนย์กลาง (องศา) ของส่วนโค้ง แล้วคำนวณความยาวส่วนโค้ง (r × θเรเดียน)

# %%
# ✍️ เขียนโค้ดข้อ 49 ที่นี่

# %% [markdown]
# **ข้อ 50.** เขียนโปรแกรมรับเงินต้น อัตราดอกเบี้ยต่อปี (%) และจำนวนปี แล้วคำนวณดอกเบี้ยทบต้น P×(1+r/100)^t

# %%
# ✍️ เขียนโค้ดข้อ 50 ที่นี่
