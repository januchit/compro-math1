# %% [markdown]
# # 040223101 การเขียนโปรแกรมคอมพิวเตอร์สำหรับคณิตศาสตร์ 1
# ## (Computer Programming for Mathematics 1)
#
# # แบบฝึกหัด บทที่ 4: โครงสร้างการตัดสินใจ
# ### Conditional Structure
#
# **ผู้สอน:** รศ.ดร.อนุชิต จิตพัฒนกุล
# ภาควิชาคณิตศาสตร์ คณะวิทยาศาสตร์ประยุกต์  มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าพระนครเหนือ
#
# ---
#
# ### 📝 คำชี้แจง
# - ให้นักศึกษาเขียนโปรแกรมภาษา Python แก้โจทย์แต่ละข้อในเซลล์โค้ดที่เว้นว่างไว้ใต้โจทย์
# - กดปุ่ม **▶ Run** (หรือ Shift+Enter) เพื่อรันโค้ดและตรวจผลลัพธ์
# - โจทย์แบ่งเป็น 3 ระดับจากง่ายไปยาก ควรทำไล่ตามลำดับ
# - เขียนชื่อ-รหัสนักศึกษาของคุณในเซลล์ด้านล่างก่อนเริ่มทำ

# %%
# ✏️ กรอกข้อมูลของคุณ
student_name = ""   # ชื่อ-นามสกุล
student_id = ""     # รหัสนักศึกษา
print("ผู้ทำแบบฝึกหัด:", student_name, student_id)

# %% [markdown]
# ### 🔧 ระบบตรวจคำตอบ
# รันเซลล์ด้านล่าง **หนึ่งครั้ง** ก่อนเริ่มทำ จากนั้นเมื่อทำข้อใดเสร็จ ให้รันเซลล์ `ตรวจ(เลขข้อ)` ที่อยู่ใต้ข้อนั้น เพื่อตรวจว่าคำตอบถูกหรือยัง

# %%
# 🔧 ระบบตรวจคำตอบอัตโนมัติ — รันเซลล์นี้ "หนึ่งครั้ง" ก่อนเริ่มทำแบบฝึกหัด
# วิธีใช้: เขียนคำตอบในเซลล์ของแต่ละข้อ กด ▶ รันให้เห็นผลลัพธ์ก่อน
#         จากนั้นรันเซลล์  ตรวจ(เลขข้อ)  ที่อยู่ใต้ข้อนั้น เพื่อตรวจว่าถูกไหม
import io, re, contextlib, json as _json

_KEY = _json.loads(r"""{"1": {"text": ["จำนวนบวก"]}, "2": {"text": ["คู่"]}, "3": {"text": ["ผ่าน"]}, "4": {"text": ["บรรลุนิติภาวะ"]}, "5": {"text": ["มากกว่า"]}, "6": {"text": ["ศูนย์"]}, "7": {"text": ["ลงตัว"]}, "8": {"text": ["ร้อน"]}, "9": {"text": ["ลบ"]}, "10": {"text": ["แพง"]}, "11": {"num": [8]}, "12": {"text": ["ดีมาก"]}, "13": {"text": ["หลักเดียว"]}, "14": {"num": [20], "text": ["ถึงเกณฑ์"]}, "15": {"num": [12]}, "16": {"text": ["สูงเกินเกณฑ์"]}, "17": {"text": ["คู่บวก"]}, "18": {"text": ["เปิด"]}, "19": {"text": ["ซื้อได้"]}, "20": {"text": ["ลงตัวทั้งคู่"]}, "21": {"text": ["B"]}, "22": {"text": ["อธิกสุรทิน"]}, "23": {"num": [25]}, "24": {"text": ["ปกติ"]}, "25": {"text": ["เป็นสามเหลี่ยมได้"]}, "26": {"text": ["บ่าย"]}, "27": {"text": ["YES"]}, "28": {"text": ["ด้านเท่า"]}, "29": {"text": ["YES"]}, "30": {"num": [500]}, "31": {"num": [3]}, "32": {"text": ["YES"]}, "33": {"text": ["ผ่าน"]}, "34": {"text": ["YES"]}, "35": {"num": [12]}, "36": {"text": ["NO"]}, "37": {"num": [6000]}, "38": {"text": ["ผ่านทุกวิชา"]}, "39": {"text": ["คู่บวก"]}, "40": {"num": [60]}, "41": {"num": [2]}, "42": {"num": [2, 5, 8]}, "43": {"text": ["NO"]}, "44": {"num": [5]}, "45": {"text": ["สระ"]}, "46": {"num": [2700]}, "47": {"text": ["A"]}, "48": {"text": ["มุมฉาก"]}, "49": {"text": ["YES"]}, "50": {"num": [59]}}""")
_KEY = {int(k): v for k, v in _KEY.items()}

def _หาโค้ด(qno):
    marker = "เขียนโค้ดข้อ %d ที่นี่" % qno
    hist = _ih[:-1]                       # ไม่รวมเซลล์ตรวจที่กำลังรันอยู่
    for src in reversed(hist):
        if marker in src:
            return src
    return hist[-1] if hist else None     # สำรอง: เซลล์ที่รันก่อนหน้า

def _ไม่มีโค้ด(code):
    if not code:
        return True
    body = "\n".join(l for l in code.splitlines() if not l.strip().startswith("#"))
    return body.strip() == ""

def _ตัวเลข(s):
    return [float(x) for x in re.findall(r"-?\d+\.?\d*", s)]

def _นอร์ม(s):
    return s.replace(" ", "").replace("\t", "").replace("\n", "").lower()

def ตรวจ(qno):
    item = _KEY.get(qno)
    if item is None:
        print("ยังไม่มีเฉลยของข้อ", qno); return
    code = _หาโค้ด(qno)
    if _ไม่มีโค้ด(code):
        print("⚠️  ข้อ %d: ยังไม่พบโค้ดคำตอบ — กรุณารันเซลล์คำตอบของข้อนี้ก่อน แล้วค่อยรันเซลล์ตรวจอีกครั้ง" % qno)
        return
    try:
        buf = io.StringIO()
        with contextlib.redirect_stdout(buf):
            exec(compile(code, "<คำตอบข้อ %d>" % qno, "exec"), {})
        out = buf.getvalue()
    except Exception as e:
        print("❌  ข้อ %d: โค้ดรันแล้วเกิดข้อผิดพลาด → %s: %s" % (qno, type(e).__name__, e))
        return

    if item.get("manual"):
        if out.strip():
            print("ℹ️  ข้อ %d: ข้อนี้ขึ้นกับข้อมูลของนักศึกษา ระบบตรวจอัตโนมัติให้ไม่ได้" % qno)
            print("    โปรแกรมของคุณแสดงผลว่า:")
            for line in out.rstrip().splitlines():
                print("      ", line)
            print("    ✔️  ถ้าผลตรงกับที่โจทย์ต้องการ ถือว่าผ่าน")
        else:
            print("⚠️  ข้อ %d: ยังไม่มีผลลัพธ์แสดงออกมา ลองตรวจว่าใช้ print() แล้วหรือยัง" % qno)
        return

    problems = []
    if "text" in item:
        n = _นอร์ม(out)
        for t in item["text"]:
            if _นอร์ม(t) not in n:
                problems.append("ต้องมีข้อความ: %s" % t)
    if "num" in item:
        nums = _ตัวเลข(out)
        tol = item.get("tol")
        for v in item["num"]:
            ok = any(abs(v - x) <= (tol if tol is not None else max(1e-6, abs(v) * 1e-4)) for x in nums)
            if not ok:
                problems.append("ต้องมีค่า: %s" % (("%g" % v)))

    if not problems:
        print("✅  ข้อ %d: ถูกต้อง! เก่งมาก 🎉" % qno)
    else:
        print("❌  ข้อ %d: ยังไม่ถูก" % qno)
        for p in problems:
            print("     • " + p)
        shown = out.strip() if out.strip() else "(ไม่มีผลลัพธ์ — ใช้ print() หรือยัง?)"
        print("     ผลลัพธ์ที่โปรแกรมของคุณแสดง: %s" % shown)

print("✅ พร้อมตรวจคำตอบแล้ว — ทำข้อไหนเสร็จ ให้รันเซลล์  ตรวจ(เลขข้อ)  ใต้ข้อนั้นได้เลย")

# %% [markdown]
# ---
# ## ระดับที่ 1 — พื้นฐาน (Basic)
# _ฝึกใช้คำสั่งและไวยากรณ์พื้นฐานของบทนี้ให้คล่อง_

# %% [markdown]
# **ข้อ 1.** กำหนด `n = 7` ถ้า `n` มากกว่า 0 ให้แสดงข้อความ `จำนวนบวก`

# %%
# ✍️ เขียนโค้ดข้อ 1 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 1 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(1)

# %% [markdown]
# **ข้อ 2.** กำหนด `n = 8` ถ้าเป็นจำนวนคู่ให้แสดง `คู่` ถ้าเป็นจำนวนคี่ให้แสดง `คี่`

# %%
# ✍️ เขียนโค้ดข้อ 2 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 2 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(2)

# %% [markdown]
# **ข้อ 3.** กำหนดคะแนน `score = 55` ถ้าตั้งแต่ 50 ขึ้นไปให้แสดง `ผ่าน` มิฉะนั้นแสดง `ตก`

# %%
# ✍️ เขียนโค้ดข้อ 3 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 3 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(3)

# %% [markdown]
# **ข้อ 4.** กำหนดอายุ `age = 20` ถ้าตั้งแต่ 18 ปีขึ้นไปให้แสดง `บรรลุนิติภาวะ`

# %%
# ✍️ เขียนโค้ดข้อ 4 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 4 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(4)

# %% [markdown]
# **ข้อ 5.** กำหนด `a = 9`, `b = 4` ถ้า `a` มากกว่า `b` ให้แสดง `มากกว่า` มิฉะนั้นแสดง `น้อยกว่าหรือเท่ากัน`

# %%
# ✍️ เขียนโค้ดข้อ 5 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 5 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(5)

# %% [markdown]
# **ข้อ 6.** กำหนด `n = 0` ถ้าเท่ากับ 0 ให้แสดง `ศูนย์` มิฉะนั้นแสดง `มีค่า`

# %%
# ✍️ เขียนโค้ดข้อ 6 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 6 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(6)

# %% [markdown]
# **ข้อ 7.** กำหนด `n = 25` ถ้าหารด้วย 5 ลงตัวให้แสดง `ลงตัว` มิฉะนั้นแสดง `เหลือเศษ`

# %%
# ✍️ เขียนโค้ดข้อ 7 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 7 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(7)

# %% [markdown]
# **ข้อ 8.** กำหนดอุณหภูมิ `temp = 38` ถ้าเกิน 35 องศาให้แสดง `ร้อน`

# %%
# ✍️ เขียนโค้ดข้อ 8 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 8 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(8)

# %% [markdown]
# **ข้อ 9.** กำหนด `n = -5` แล้วแสดง `บวก` `ลบ` หรือ `ศูนย์` ตามค่าของ `n`

# %%
# ✍️ เขียนโค้ดข้อ 9 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 9 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(9)

# %% [markdown]
# **ข้อ 10.** กำหนดราคา `price = 1200` ถ้าเกิน 1000 บาทให้แสดง `แพง` มิฉะนั้นแสดง `ราคาปกติ`

# %%
# ✍️ เขียนโค้ดข้อ 10 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 10 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(10)

# %% [markdown]
# **ข้อ 11.** กำหนด `n = -8` แล้วแสดงค่าสัมบูรณ์โดยใช้เงื่อนไข (ไม่ใช้ abs)

# %%
# ✍️ เขียนโค้ดข้อ 11 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 11 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(11)

# %% [markdown]
# **ข้อ 12.** กำหนดคะแนนสอบ `score = 85` ถ้าตั้งแต่ 80 ขึ้นไปให้แสดง `ดีมาก`

# %%
# ✍️ เขียนโค้ดข้อ 12 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 12 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(12)

# %% [markdown]
# **ข้อ 13.** กำหนด `n = 7` ถ้าเป็นเลขหลักเดียว (0-9) ให้แสดง `หลักเดียว` มิฉะนั้นแสดง `หลายหลัก`

# %%
# ✍️ เขียนโค้ดข้อ 13 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 13 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(13)

# %% [markdown]
# **ข้อ 14.** กำหนดปีเกิด `birth = 2549` คำนวณอายุปี 2569 แสดงอายุ และถ้าอายุถึง 20 ปีให้แสดง `ถึงเกณฑ์`

# %%
# ✍️ เขียนโค้ดข้อ 14 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 14 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(14)

# %% [markdown]
# **ข้อ 15.** กำหนด `a = 12`, `b = 8` แล้วแสดงค่าที่มากกว่า

# %%
# ✍️ เขียนโค้ดข้อ 15 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 15 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(15)

# %% [markdown]
# **ข้อ 16.** กำหนดส่วนสูง `h = 160` ซม. ถ้าเกิน 150 ซม. ให้แสดง `สูงเกินเกณฑ์`

# %%
# ✍️ เขียนโค้ดข้อ 16 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 16 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(16)

# %% [markdown]
# **ข้อ 17.** กำหนด `n = 8` ถ้าเป็นจำนวนคู่และมากกว่า 0 ให้แสดง `คู่บวก` มิฉะนั้นแสดง `ไม่เข้าเงื่อนไข`

# %%
# ✍️ เขียนโค้ดข้อ 17 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 17 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(17)

# %% [markdown]
# **ข้อ 18.** กำหนด `x = 1` ถ้าเป็น 1 ให้แสดง `เปิด` ถ้าเป็น 0 ให้แสดง `ปิด`

# %%
# ✍️ เขียนโค้ดข้อ 18 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 18 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(18)

# %% [markdown]
# **ข้อ 19.** กำหนดเงิน `money = 500` และราคา `price = 300` ถ้าซื้อได้ให้แสดง `ซื้อได้` มิฉะนั้นแสดง `เงินไม่พอ`

# %%
# ✍️ เขียนโค้ดข้อ 19 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 19 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(19)

# %% [markdown]
# **ข้อ 20.** กำหนด `n = 12` ถ้าหารด้วยทั้ง 2 และ 3 ลงตัวให้แสดง `ลงตัวทั้งคู่` มิฉะนั้นแสดง `ไม่เข้าเงื่อนไข`

# %%
# ✍️ เขียนโค้ดข้อ 20 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 20 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(20)

# %% [markdown]
# ---
# ## ระดับที่ 2 — ปานกลาง (Intermediate)
# _ประยุกต์ความรู้แก้โจทย์ที่ซับซ้อนขึ้นและผสมหลายแนวคิด_

# %% [markdown]
# **ข้อ 21.** กำหนดคะแนน `score = 75` แล้วแสดงเกรด: A(80+) B(70+) C(60+) D(50+) F(ต่ำกว่า 50) — แสดงเฉพาะตัวอักษรเกรด

# %%
# ✍️ เขียนโค้ดข้อ 21 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 21 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(21)

# %% [markdown]
# **ข้อ 22.** กำหนดปี ค.ศ. `year = 2024` ถ้าเป็นปีอธิกสุรทินให้แสดง `อธิกสุรทิน` มิฉะนั้นแสดง `ปีปกติ`

# %%
# ✍️ เขียนโค้ดข้อ 22 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 22 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(22)

# %% [markdown]
# **ข้อ 23.** กำหนด `a = 12`, `b = 25`, `c = 18` แล้วแสดงค่าที่มากที่สุด

# %%
# ✍️ เขียนโค้ดข้อ 23 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 23 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(23)

# %% [markdown]
# **ข้อ 24.** กำหนดค่า `bmi = 22.5` แล้วแสดงเกณฑ์: `ผอม`(<18.5) `ปกติ`(18.5-24.9) `น้ำหนักเกิน`(25-29.9) `อ้วน`(>=30)

# %%
# ✍️ เขียนโค้ดข้อ 24 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 24 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(24)

# %% [markdown]
# **ข้อ 25.** กำหนดด้าน `a = 3`, `b = 4`, `c = 5` ถ้าประกอบเป็นสามเหลี่ยมได้ให้แสดง `เป็นสามเหลี่ยมได้` มิฉะนั้นแสดง `สร้างไม่ได้`

# %%
# ✍️ เขียนโค้ดข้อ 25 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 25 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(25)

# %% [markdown]
# **ข้อ 26.** กำหนดชั่วโมง `hour = 14` (0-23) แล้วแสดงช่วงเวลา: `เช้า`(6-11) `บ่าย`(12-17) `เย็น`(18-20) `กลางคืน`(อื่น ๆ)

# %%
# ✍️ เขียนโค้ดข้อ 26 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 26 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(26)

# %% [markdown]
# **ข้อ 27.** กำหนด `n = 9` ถ้าหารด้วย 3 หรือ 5 ลงตัว (อย่างน้อยหนึ่ง) ให้แสดง `YES` มิฉะนั้นแสดง `NO`

# %%
# ✍️ เขียนโค้ดข้อ 27 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 27 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(27)

# %% [markdown]
# **ข้อ 28.** กำหนดด้าน `a = 5`, `b = 5`, `c = 5` แล้วจัดประเภท: `ด้านเท่า` `หน้าจั่ว` หรือ `ด้านไม่เท่า`

# %%
# ✍️ เขียนโค้ดข้อ 28 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 28 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(28)

# %% [markdown]
# **ข้อ 29.** กำหนด `n = 42` ถ้าเป็นเลขสองหลัก (10-99) ให้แสดง `YES` มิฉะนั้นแสดง `NO`

# %%
# ✍️ เขียนโค้ดข้อ 29 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 29 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(29)

# %% [markdown]
# **ข้อ 30.** กำหนดหน่วยไฟฟ้า `unit = 120` คิดหน่วยละ 4 บาทถ้าไม่เกิน 100 หน่วย ส่วนเกินหน่วยละ 5 บาท แล้วแสดงค่าไฟ

# %%
# ✍️ เขียนโค้ดข้อ 30 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 30 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(30)

# %% [markdown]
# **ข้อ 31.** กำหนดเกรด `grade = "B"` แล้วแสดงค่าระดับคะแนน (A=4, B=3, C=2, D=1, F=0)

# %%
# ✍️ เขียนโค้ดข้อ 31 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 31 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(31)

# %% [markdown]
# **ข้อ 32.** กำหนด `n = 8` ถ้าเป็นพหุคูณของ 4 แต่ไม่เป็นพหุคูณของ 100 ให้แสดง `YES` มิฉะนั้นแสดง `NO`

# %%
# ✍️ เขียนโค้ดข้อ 32 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 32 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(32)

# %% [markdown]
# **ข้อ 33.** กำหนดคะแนนเก็บ `collect = 40` คะแนนสอบ `exam = 30` ถ้าผลรวมตั้งแต่ 60 และคะแนนสอบไม่น้อยกว่า 25 ให้แสดง `ผ่าน` มิฉะนั้นแสดง `ตก`

# %%
# ✍️ เขียนโค้ดข้อ 33 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 33 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(33)

# %% [markdown]
# **ข้อ 34.** กำหนด `n = 50` ถ้าอยู่ในช่วง 1 ถึง 100 ให้แสดง `YES` มิฉะนั้นแสดง `NO`

# %%
# ✍️ เขียนโค้ดข้อ 34 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 34 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(34)

# %% [markdown]
# **ข้อ 35.** กำหนด `a = 12`, `b = 25`, `c = 18` แล้วแสดงค่าที่น้อยที่สุด

# %%
# ✍️ เขียนโค้ดข้อ 35 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 35 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(35)

# %% [markdown]
# **ข้อ 36.** กำหนด `n = 6` (n ≤ 10) ถ้าเป็นจำนวนเฉพาะให้แสดง `YES` มิฉะนั้นแสดง `NO`

# %%
# ✍️ เขียนโค้ดข้อ 36 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 36 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(36)

# %% [markdown]
# **ข้อ 37.** กำหนดเงินเดือน `salary = 60000` คำนวณภาษี: ไม่เกิน 20000 ยกเว้น, 20001-50000 เก็บ 5%, เกิน 50000 เก็บ 10% แล้วแสดงภาษี

# %%
# ✍️ เขียนโค้ดข้อ 37 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 37 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(37)

# %% [markdown]
# **ข้อ 38.** กำหนดคะแนนสามวิชา `s1 = 60`, `s2 = 70`, `s3 = 80` ถ้าทุกวิชาได้ตั้งแต่ 50 ขึ้นไปให้แสดง `ผ่านทุกวิชา`

# %%
# ✍️ เขียนโค้ดข้อ 38 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 38 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(38)

# %% [markdown]
# **ข้อ 39.** กำหนด `n = 8` แล้วแสดง `คู่บวก` `คี่บวก` หรือ `ลบ` (สำหรับเลขที่น้อยกว่าหรือเท่ากับ 0)

# %%
# ✍️ เขียนโค้ดข้อ 39 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 39 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(39)

# %% [markdown]
# **ข้อ 40.** กำหนดน้ำหนักพัสดุ `w = 3` กก. คิดค่าส่ง 30 บาทไม่เกิน 1 กก. ส่วนเกินคิด กก.ละ 15 บาท แล้วแสดงค่าส่ง

# %%
# ✍️ เขียนโค้ดข้อ 40 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 40 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(40)

# %% [markdown]
# ---
# ## ระดับที่ 3 — ท้าทาย (Challenge)
# _โจทย์ประยุกต์เชิงคณิตศาสตร์และตรรกะที่ต้องคิดวิเคราะห์_

# %% [markdown]
# **ข้อ 41.** กำหนดสัมประสิทธิ์ `a = 1`, `b = -5`, `c = 6` แล้วแสดงจำนวนรากจริงจากดิสคริมิแนนต์ (2, 1 หรือ 0)

# %%
# ✍️ เขียนโค้ดข้อ 41 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 41 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(41)

# %% [markdown]
# **ข้อ 42.** กำหนด `a = 5`, `b = 2`, `c = 8` แล้วเรียงและแสดงจากน้อยไปมากโดยใช้เงื่อนไข (ไม่ใช้ sort)

# %%
# ✍️ เขียนโค้ดข้อ 42 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 42 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(42)

# %% [markdown]
# **ข้อ 43.** กำหนด `year = 2023`, `month = 2`, `day = 30` ตรวจว่าวันที่ถูกต้องหรือไม่ (ก.พ. 28 วัน ไม่คิดอธิกสุรทิน) แสดง `YES` หรือ `NO`

# %%
# ✍️ เขียนโค้ดข้อ 43 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 43 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(43)

# %% [markdown]
# **ข้อ 44.** กำหนดเวลาเริ่ม `start = 22` และเวลาสิ้นสุด `end = 3` (ชั่วโมงเต็ม 0-23) แล้วคำนวณจำนวนชั่วโมงที่ผ่านไป (ข้ามวันได้)

# %%
# ✍️ เขียนโค้ดข้อ 44 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 44 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(44)

# %% [markdown]
# **ข้อ 45.** กำหนด `ch = "A"` แล้วจัดประเภท: `สระ` (a,e,i,o,u) `พยัญชนะ` หรือ `ไม่ใช่ตัวอักษร`

# %%
# ✍️ เขียนโค้ดข้อ 45 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 45 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(45)

# %% [markdown]
# **ข้อ 46.** กำหนดราคา `price = 3000` คิดส่วนลด: ครบ 5000 ลด 15%, ครบ 3000 ลด 10%, ครบ 1000 ลด 5% แล้วแสดงราคาสุทธิ

# %%
# ✍️ เขียนโค้ดข้อ 46 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 46 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(46)

# %% [markdown]
# **ข้อ 47.** กำหนดคะแนน `s1 = 80`, `s2 = 70`, `s3 = 90` คำนวณค่าเฉลี่ยและตัดเกรด A(>=80) B(>=70) C(>=60) D(>=50) F — แสดงเฉพาะเกรด

# %%
# ✍️ เขียนโค้ดข้อ 47 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 47 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(47)

# %% [markdown]
# **ข้อ 48.** กำหนดมุมสามมุม `a = 90`, `b = 60`, `c = 30` (รวมได้ 180) จัดประเภทตามมุม: `มุมฉาก` `มุมป้าน` หรือ `มุมแหลม`

# %%
# ✍️ เขียนโค้ดข้อ 48 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 48 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(48)

# %% [markdown]
# **ข้อ 49.** กำหนด `n = 121` ถ้าเป็นเลขพาลินโดรมสามหลัก (หลักร้อยเท่ากับหลักหน่วย) ให้แสดง `YES` มิฉะนั้นแสดง `NO`

# %%
# ✍️ เขียนโค้ดข้อ 49 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 49 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(49)

# %% [markdown]
# **ข้อ 50.** กำหนดระยะทาง `dist = 5` กม. คำนวณค่าโดยสารแท็กซี่: 35 บาทแรกสำหรับ 1 กม.แรก จากนั้น กม.ละ 6 บาท แล้วแสดงค่าโดยสาร

# %%
# ✍️ เขียนโค้ดข้อ 50 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 50 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(50)
