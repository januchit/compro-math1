# %% [markdown]
# # 040223101 การเขียนโปรแกรมคอมพิวเตอร์สำหรับคณิตศาสตร์ 1
# ## (Computer Programming for Mathematics 1)
#
# # แบบฝึกหัด บทที่ 9: ฟังก์ชัน
# ### Functions
#
# **ผู้สอน:** รศ.ดร.อนุชิต จิตพัฒนกุล
# ภาควิชาคณิตศาสตร์ คณะวิทยาศาสตร์ประยุกต์  มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าพระนครเหนือ
#
# ---
#
# ### 📝 คำชี้แจง
# - ให้นักศึกษาเขียนโปรแกรมภาษา Python แก้โจทย์แต่ละข้อในเซลล์โค้ดที่เว้นว่างไว้ใต้โจทย์
# - กดปุ่ม **▶ Run** (หรือ Shift+Enter) เพื่อรันโค้ดและตรวจผลลัพธ์
# - โจทย์แบ่งเป็น 3 ระดับจากง่ายไปยาก ควรทำไล่ตามลำดับ
# - เขียนชื่อ-รหัสนักศึกษาของคุณในเซลล์ด้านล่างก่อนเริ่มทำ

# %%
# ✏️ กรอกข้อมูลของคุณ
student_name = ""   # ชื่อ-นามสกุล
student_id = ""     # รหัสนักศึกษา
print("ผู้ทำแบบฝึกหัด:", student_name, student_id)

# %% [markdown]
# ### 🔧 ระบบตรวจคำตอบ
# รันเซลล์ด้านล่าง **หนึ่งครั้ง** ก่อนเริ่มทำ จากนั้นเมื่อทำข้อใดเสร็จ ให้รันเซลล์ `ตรวจ(เลขข้อ)` ที่อยู่ใต้ข้อนั้น เพื่อตรวจว่าคำตอบถูกหรือยัง

# %%
# 🔧 ระบบตรวจคำตอบอัตโนมัติ — รันเซลล์นี้ "หนึ่งครั้ง" ก่อนเริ่มทำแบบฝึกหัด
# วิธีใช้: เขียนคำตอบในเซลล์ของแต่ละข้อ กด ▶ รันให้เห็นผลลัพธ์ก่อน
#         จากนั้นรันเซลล์  ตรวจ(เลขข้อ)  ที่อยู่ใต้ข้อนั้น เพื่อตรวจว่าถูกไหม
import io, re, contextlib, json as _json

_KEY = _json.loads(r"""{"1": {"text": ["สวัสดี"]}, "2": {"num": [25]}, "3": {"num": [7]}, "4": {"text": ["สวัสดีคุณ", "มานี"]}, "5": {"num": [27]}, "6": {"num": [12]}, "7": {"text": ["True"]}, "8": {"num": [15]}, "9": {"num": [9]}, "10": {"num": [8]}, "11": {"num": [86]}, "12": {"num": [78.53975], "tol": 0.01}, "13": {"num": [14]}, "14": {"num": [6]}, "15": {"text": ["HelloHelloHello"]}, "16": {"text": ["True"]}, "17": {"num": [32]}, "18": {"num": [3000]}, "19": {"num": [7, 0]}, "20": {"text": ["Guest"]}, "21": {"num": [720]}, "22": {"num": [43.98, 153.94], "tol": 0.05}, "23": {"num": [25]}, "24": {"text": ["True"]}, "25": {"num": [15]}, "26": {"num": [3]}, "27": {"num": [4, 23, 13.2], "tol": 0.05}, "28": {"num": [12]}, "29": {"num": [4321]}, "30": {"num": [21]}, "31": {"num": [1024]}, "32": {"num": [20.76], "tol": 0.05}, "33": {"text": ["True"]}, "34": {"num": [5]}, "35": {"num": [15]}, "36": {"num": [5050]}, "37": {"num": [298.15], "tol": 0.01}, "38": {"num": [6]}, "39": {"num": [0]}, "40": {"num": [5]}, "41": {"num": [720]}, "42": {"num": [55]}, "43": {"num": [5050]}, "44": {"num": [1024]}, "45": {"num": [12]}, "46": {"num": [2, 3, 5, 47]}, "47": {"num": [15]}, "48": {"num": [29]}, "49": {"num": [15]}, "50": {"num": [900]}}""")
_KEY = {int(k): v for k, v in _KEY.items()}

def _หาโค้ด(qno):
    marker = "เขียนโค้ดข้อ %d ที่นี่" % qno
    hist = _ih[:-1]                       # ไม่รวมเซลล์ตรวจที่กำลังรันอยู่
    for src in reversed(hist):
        if marker in src:
            return src
    return hist[-1] if hist else None     # สำรอง: เซลล์ที่รันก่อนหน้า

def _ไม่มีโค้ด(code):
    if not code:
        return True
    body = "\n".join(l for l in code.splitlines() if not l.strip().startswith("#"))
    return body.strip() == ""

def _ตัวเลข(s):
    return [float(x) for x in re.findall(r"-?\d+\.?\d*", s)]

def _นอร์ม(s):
    return s.replace(" ", "").replace("\t", "").replace("\n", "").lower()

def ตรวจ(qno):
    item = _KEY.get(qno)
    if item is None:
        print("ยังไม่มีเฉลยของข้อ", qno); return
    code = _หาโค้ด(qno)
    if _ไม่มีโค้ด(code):
        print("⚠️  ข้อ %d: ยังไม่พบโค้ดคำตอบ — กรุณารันเซลล์คำตอบของข้อนี้ก่อน แล้วค่อยรันเซลล์ตรวจอีกครั้ง" % qno)
        return
    try:
        buf = io.StringIO()
        with contextlib.redirect_stdout(buf):
            exec(compile(code, "<คำตอบข้อ %d>" % qno, "exec"), {})
        out = buf.getvalue()
    except Exception as e:
        print("❌  ข้อ %d: โค้ดรันแล้วเกิดข้อผิดพลาด → %s: %s" % (qno, type(e).__name__, e))
        return

    if item.get("manual"):
        if out.strip():
            print("ℹ️  ข้อ %d: ข้อนี้ขึ้นกับข้อมูลของนักศึกษา ระบบตรวจอัตโนมัติให้ไม่ได้" % qno)
            print("    โปรแกรมของคุณแสดงผลว่า:")
            for line in out.rstrip().splitlines():
                print("      ", line)
            print("    ✔️  ถ้าผลตรงกับที่โจทย์ต้องการ ถือว่าผ่าน")
        else:
            print("⚠️  ข้อ %d: ยังไม่มีผลลัพธ์แสดงออกมา ลองตรวจว่าใช้ print() แล้วหรือยัง" % qno)
        return

    problems = []
    if "text" in item:
        n = _นอร์ม(out)
        for t in item["text"]:
            if _นอร์ม(t) not in n:
                problems.append("ต้องมีข้อความ: %s" % t)
    if "num" in item:
        nums = _ตัวเลข(out)
        tol = item.get("tol")
        for v in item["num"]:
            ok = any(abs(v - x) <= (tol if tol is not None else max(1e-6, abs(v) * 1e-4)) for x in nums)
            if not ok:
                problems.append("ต้องมีค่า: %s" % (("%g" % v)))

    if not problems:
        print("✅  ข้อ %d: ถูกต้อง! เก่งมาก 🎉" % qno)
    else:
        print("❌  ข้อ %d: ยังไม่ถูก" % qno)
        for p in problems:
            print("     • " + p)
        shown = out.strip() if out.strip() else "(ไม่มีผลลัพธ์ — ใช้ print() หรือยัง?)"
        print("     ผลลัพธ์ที่โปรแกรมของคุณแสดง: %s" % shown)

print("✅ พร้อมตรวจคำตอบแล้ว — ทำข้อไหนเสร็จ ให้รันเซลล์  ตรวจ(เลขข้อ)  ใต้ข้อนั้นได้เลย")

# %% [markdown]
# ---
# ## ระดับที่ 1 — พื้นฐาน (Basic)
# _ฝึกใช้คำสั่งและไวยากรณ์พื้นฐานของบทนี้ให้คล่อง_

# %% [markdown]
# **ข้อ 1.** เขียนฟังก์ชัน `greet()` ที่แสดงข้อความ `สวัสดี` แล้วเรียกใช้

# %%
# ✍️ เขียนโค้ดข้อ 1 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 1 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(1)

# %% [markdown]
# **ข้อ 2.** เขียนฟังก์ชัน `square(x)` ที่คืนค่ากำลังสองของ x แล้วแสดงผลของ `square(5)`

# %%
# ✍️ เขียนโค้ดข้อ 2 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 2 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(2)

# %% [markdown]
# **ข้อ 3.** เขียนฟังก์ชัน `add(a, b)` ที่คืนผลบวกของ a และ b แล้วแสดงผลของ `add(3, 4)`

# %%
# ✍️ เขียนโค้ดข้อ 3 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 3 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(3)

# %% [markdown]
# **ข้อ 4.** เขียนฟังก์ชัน `greet_name(name)` ที่แสดง `สวัสดีคุณ` ตามด้วยชื่อ แล้วเรียก `greet_name("มานี")`

# %%
# ✍️ เขียนโค้ดข้อ 4 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 4 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(4)

# %% [markdown]
# **ข้อ 5.** เขียนฟังก์ชัน `cube(x)` ที่คืนค่ากำลังสามของ x แล้วแสดงผลของ `cube(3)`

# %%
# ✍️ เขียนโค้ดข้อ 5 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 5 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(5)

# %% [markdown]
# **ข้อ 6.** เขียนฟังก์ชัน `triangle_area(b, h)` ที่คืนพื้นที่สามเหลี่ยม (½×b×h) แล้วแสดงผลของ `triangle_area(6, 4)`

# %%
# ✍️ เขียนโค้ดข้อ 6 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 6 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(6)

# %% [markdown]
# **ข้อ 7.** เขียนฟังก์ชัน `is_even(n)` ที่คืน True ถ้า n เป็นเลขคู่ แล้วแสดงผลของ `is_even(8)`

# %%
# ✍️ เขียนโค้ดข้อ 7 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 7 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(7)

# %% [markdown]
# **ข้อ 8.** เขียนฟังก์ชัน `rectangle_area(w, l)` ที่คืนพื้นที่สี่เหลี่ยมผืนผ้า แล้วแสดงผลของ `rectangle_area(5, 3)`

# %%
# ✍️ เขียนโค้ดข้อ 8 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 8 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(8)

# %% [markdown]
# **ข้อ 9.** เขียนฟังก์ชัน `maximum(a, b)` ที่คืนค่าที่มากกว่าระหว่าง a กับ b แล้วแสดงผลของ `maximum(9, 4)`

# %%
# ✍️ เขียนโค้ดข้อ 9 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 9 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(9)

# %% [markdown]
# **ข้อ 10.** เขียนฟังก์ชัน `absolute(x)` ที่คืนค่าสัมบูรณ์ของ x (ไม่ใช้ abs) แล้วแสดงผลของ `absolute(-8)`

# %%
# ✍️ เขียนโค้ดข้อ 10 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 10 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(10)

# %% [markdown]
# **ข้อ 11.** เขียนฟังก์ชัน `to_fahrenheit(c)` ที่แปลงเซลเซียสเป็นฟาเรนไฮต์ (c×9/5+32) แล้วแสดงผลของ `to_fahrenheit(30)`

# %%
# ✍️ เขียนโค้ดข้อ 11 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 11 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(11)

# %% [markdown]
# **ข้อ 12.** เขียนฟังก์ชัน `circle_area(r)` ที่คืนพื้นที่วงกลม (ใช้ 3.14159) แล้วแสดงผลของ `circle_area(5)`

# %%
# ✍️ เขียนโค้ดข้อ 12 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 12 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(12)

# %% [markdown]
# **ข้อ 13.** เขียนฟังก์ชัน `double(x)` ที่คืนค่าสองเท่าของ x แล้วแสดงผลของ `double(7)`

# %%
# ✍️ เขียนโค้ดข้อ 13 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 13 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(13)

# %% [markdown]
# **ข้อ 14.** เขียนฟังก์ชัน `average3(a, b, c)` ที่คืนค่าเฉลี่ยของสามจำนวน แล้วแสดงผลของ `average3(3, 6, 9)`

# %%
# ✍️ เขียนโค้ดข้อ 14 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 14 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(14)

# %% [markdown]
# **ข้อ 15.** เขียนฟังก์ชัน `greet_times(n)` ที่แสดง `Hello` จำนวน n ครั้ง แล้วเรียก `greet_times(3)`

# %%
# ✍️ เขียนโค้ดข้อ 15 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 15 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(15)

# %% [markdown]
# **ข้อ 16.** เขียนฟังก์ชัน `is_positive(n)` ที่คืน True ถ้า n มากกว่า 0 แล้วแสดงผลของ `is_positive(5)`

# %%
# ✍️ เขียนโค้ดข้อ 16 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 16 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(16)

# %% [markdown]
# **ข้อ 17.** เขียนฟังก์ชัน `power(base, exp)` ที่คืน base ยกกำลัง exp แล้วแสดงผลของ `power(2, 5)`

# %%
# ✍️ เขียนโค้ดข้อ 17 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 17 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(17)

# %% [markdown]
# **ข้อ 18.** เขียนฟังก์ชัน `km_to_m(km)` ที่แปลงกิโลเมตรเป็นเมตร แล้วแสดงผลของ `km_to_m(3)`

# %%
# ✍️ เขียนโค้ดข้อ 18 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 18 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(18)

# %% [markdown]
# **ข้อ 19.** เขียนฟังก์ชัน `subtract(a, b)` ที่คืนผลลบ a−b แล้วเรียกใช้สองครั้ง: `subtract(10, 3)` และ `subtract(8, 8)`

# %%
# ✍️ เขียนโค้ดข้อ 19 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 19 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(19)

# %% [markdown]
# **ข้อ 20.** เขียนฟังก์ชัน `greet_default(name="Guest")` ที่แสดงชื่อ โดยมีค่าปริยายเป็น Guest แล้วเรียกโดยไม่ใส่อาร์กิวเมนต์

# %%
# ✍️ เขียนโค้ดข้อ 20 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 20 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(20)

# %% [markdown]
# ---
# ## ระดับที่ 2 — ปานกลาง (Intermediate)
# _ประยุกต์ความรู้แก้โจทย์ที่ซับซ้อนขึ้นและผสมหลายแนวคิด_

# %% [markdown]
# **ข้อ 21.** เขียนฟังก์ชัน `factorial(n)` ที่คืนค่าแฟกทอเรียลของ n ด้วยลูป แล้วแสดงผลของ `factorial(6)`

# %%
# ✍️ เขียนโค้ดข้อ 21 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 21 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(21)

# %% [markdown]
# **ข้อ 22.** เขียนฟังก์ชัน `circle(r)` ที่คืนทั้งเส้นรอบวงและพื้นที่ของวงกลม (ใช้ 3.14159) แล้วแสดงผลของ `circle(7)` ทศนิยม 2 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 22 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 22 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(22)

# %% [markdown]
# **ข้อ 23.** เขียนฟังก์ชัน `maximum3(a, b, c)` ที่คืนค่าที่มากที่สุดในสามจำนวน แล้วแสดงผลของ `maximum3(12, 25, 18)`

# %%
# ✍️ เขียนโค้ดข้อ 23 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 23 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(23)

# %% [markdown]
# **ข้อ 24.** เขียนฟังก์ชัน `is_prime(n)` ที่คืน True ถ้า n เป็นจำนวนเฉพาะ แล้วแสดงผลของ `is_prime(29)`

# %%
# ✍️ เขียนโค้ดข้อ 24 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 24 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(24)

# %% [markdown]
# **ข้อ 25.** เขียนฟังก์ชัน `sum_list(numbers)` ที่คืนผลรวมของสมาชิกในลิสต์ แล้วแสดงผลของ `sum_list([1, 2, 3, 4, 5])`

# %%
# ✍️ เขียนโค้ดข้อ 25 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 25 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(25)

# %% [markdown]
# **ข้อ 26.** เขียนฟังก์ชัน `count_even(numbers)` ที่คืนจำนวนเลขคู่ในลิสต์ แล้วแสดงผลของ `count_even([1, 2, 3, 4, 5, 6])`

# %%
# ✍️ เขียนโค้ดข้อ 26 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 26 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(26)

# %% [markdown]
# **ข้อ 27.** เขียนฟังก์ชัน `stat(numbers)` ที่คืนค่าต่ำสุด สูงสุด และเฉลี่ยของลิสต์ แล้วแสดงผลของ `stat([4, 8, 15, 16, 23])` (เฉลี่ยทศนิยม 2 ตำแหน่ง)

# %%
# ✍️ เขียนโค้ดข้อ 27 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 27 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(27)

# %% [markdown]
# **ข้อ 28.** เขียนฟังก์ชัน `gcd(a, b)` ที่คืน ห.ร.ม. ด้วยอัลกอริทึมยุคลิด แล้วแสดงผลของ `gcd(48, 36)`

# %%
# ✍️ เขียนโค้ดข้อ 28 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 28 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(28)

# %% [markdown]
# **ข้อ 29.** เขียนฟังก์ชัน `reverse_number(n)` ที่คืนเลขที่กลับหลักแล้ว แล้วแสดงผลของ `reverse_number(1234)`

# %%
# ✍️ เขียนโค้ดข้อ 29 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 29 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(29)

# %% [markdown]
# **ข้อ 30.** เขียนฟังก์ชัน `digit_sum(n)` ที่คืนผลรวมของหลักทุกหลัก แล้วแสดงผลของ `digit_sum(4827)`

# %%
# ✍️ เขียนโค้ดข้อ 30 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 30 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(30)

# %% [markdown]
# **ข้อ 31.** เขียนฟังก์ชัน `power_loop(base, exp)` ที่คืน base ยกกำลัง exp ด้วยลูป (ไม่ใช้ **) แล้วแสดงผลของ `power_loop(2, 10)`

# %%
# ✍️ เขียนโค้ดข้อ 31 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 31 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(31)

# %% [markdown]
# **ข้อ 32.** เขียนฟังก์ชัน `bmi(weight, height)` ที่คืนค่า BMI (w/h²) แล้วแสดงผลของ `bmi(60, 1.7)` ทศนิยม 2 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 32 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 32 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(32)

# %% [markdown]
# **ข้อ 33.** เขียนฟังก์ชัน `is_leap(year)` ที่คืน True ถ้าเป็นปีอธิกสุรทิน แล้วแสดงผลของ `is_leap(2024)`

# %%
# ✍️ เขียนโค้ดข้อ 33 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 33 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(33)

# %% [markdown]
# **ข้อ 34.** เขียนฟังก์ชัน `count_vowels(text)` ที่นับจำนวนสระภาษาอังกฤษ แล้วแสดงผลของ `count_vowels("education")`

# %%
# ✍️ เขียนโค้ดข้อ 34 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 34 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(34)

# %% [markdown]
# **ข้อ 35.** เขียนฟังก์ชัน `max_in_list(numbers)` ที่คืนค่ามากที่สุด (ไม่ใช้ max) แล้วแสดงผลของ `max_in_list([3, 9, 2, 15, 7])`

# %%
# ✍️ เขียนโค้ดข้อ 35 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 35 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(35)

# %% [markdown]
# **ข้อ 36.** เขียนฟังก์ชัน `sum_to(n)` ที่คืนผลรวม 1 ถึง n แล้วแสดงผลของ `sum_to(100)`

# %%
# ✍️ เขียนโค้ดข้อ 36 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 36 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(36)

# %% [markdown]
# **ข้อ 37.** เขียนฟังก์ชัน `celsius_to_kelvin(c=0)` ที่มีค่าปริยาย c=0 แปลงเป็นเคลวิน (c+273.15) แล้วแสดงผลของ `celsius_to_kelvin(25)`

# %%
# ✍️ เขียนโค้ดข้อ 37 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 37 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(37)

# %% [markdown]
# **ข้อ 38.** เขียนฟังก์ชัน `count_divisors(n)` ที่คืนจำนวนตัวหารของ n แล้วแสดงผลของ `count_divisors(12)`

# %%
# ✍️ เขียนโค้ดข้อ 38 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 38 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(38)

# %% [markdown]
# **ข้อ 39.** เขียนฟังก์ชัน `average(numbers)` ที่คืนค่าเฉลี่ยของลิสต์ และคืน 0 ถ้าลิสต์ว่าง แล้วแสดงผลของ `average([])`

# %%
# ✍️ เขียนโค้ดข้อ 39 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 39 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(39)

# %% [markdown]
# **ข้อ 40.** เขียนฟังก์ชัน `hypotenuse(a, b)` ที่คืนความยาวด้านตรงข้ามมุมฉาก (√(a²+b²)) แล้วแสดงผลของ `hypotenuse(3, 4)`

# %%
# ✍️ เขียนโค้ดข้อ 40 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 40 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(40)

# %% [markdown]
# ---
# ## ระดับที่ 3 — ท้าทาย (Challenge)
# _โจทย์ประยุกต์เชิงคณิตศาสตร์และตรรกะที่ต้องคิดวิเคราะห์_

# %% [markdown]
# **ข้อ 41.** เขียนฟังก์ชันเรียกซ้ำ (recursive) `factorial(n)` ที่คืนค่าแฟกทอเรียลของ n แล้วแสดงผลของ `factorial(6)`

# %%
# ✍️ เขียนโค้ดข้อ 41 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 41 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(41)

# %% [markdown]
# **ข้อ 42.** เขียนฟังก์ชันเรียกซ้ำ `fibonacci(n)` ที่คืนพจน์ที่ n ของลำดับฟีโบนัชชี (fib(0)=0, fib(1)=1) แล้วแสดงผลของ `fibonacci(10)`

# %%
# ✍️ เขียนโค้ดข้อ 42 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 42 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(42)

# %% [markdown]
# **ข้อ 43.** เขียนฟังก์ชันเรียกซ้ำ `sum_to(n)` ที่คืนผลรวม 1 ถึง n แล้วแสดงผลของ `sum_to(100)`

# %%
# ✍️ เขียนโค้ดข้อ 43 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 43 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(43)

# %% [markdown]
# **ข้อ 44.** เขียนฟังก์ชันเรียกซ้ำ `power(base, exp)` ที่คืน base ยกกำลัง exp แล้วแสดงผลของ `power(2, 10)`

# %%
# ✍️ เขียนโค้ดข้อ 44 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 44 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(44)

# %% [markdown]
# **ข้อ 45.** เขียนฟังก์ชันเรียกซ้ำ `gcd(a, b)` ด้วยอัลกอริทึมยุคลิด แล้วแสดงผลของ `gcd(48, 36)`

# %%
# ✍️ เขียนโค้ดข้อ 45 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 45 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(45)

# %% [markdown]
# **ข้อ 46.** เขียนฟังก์ชัน `is_prime(n)` แล้วใช้พิมพ์จำนวนเฉพาะในช่วง 2 ถึง 50

# %%
# ✍️ เขียนโค้ดข้อ 46 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 46 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(46)

# %% [markdown]
# **ข้อ 47.** เขียนฟังก์ชัน `combination(n, r)` ที่คืนค่า C(n,r) = n!/(r!(n−r)!) โดยเรียกใช้ฟังก์ชัน factorial แล้วแสดงผลของ `combination(6, 2)`

# %%
# ✍️ เขียนโค้ดข้อ 47 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 47 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(47)

# %% [markdown]
# **ข้อ 48.** เขียนฟังก์ชันเรียกซ้ำ `sum_digits(n)` ที่คืนผลรวมของหลักทุกหลัก แล้วแสดงผลของ `sum_digits(9875)`

# %%
# ✍️ เขียนโค้ดข้อ 48 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 48 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(48)

# %% [markdown]
# **ข้อ 49.** เขียนฟังก์ชัน `count_primes(limit)` ที่คืนจำนวนของจำนวนเฉพาะที่ไม่เกิน limit แล้วแสดงผลของ `count_primes(50)`

# %%
# ✍️ เขียนโค้ดข้อ 49 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 49 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(49)

# %% [markdown]
# **ข้อ 50.** เขียนฟังก์ชัน `apply_discount(price, percent=10)` ที่คืนราคาหลังหักส่วนลด มีค่าปริยาย 10% แล้วแสดงผลของ `apply_discount(1000)`

# %%
# ✍️ เขียนโค้ดข้อ 50 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 50 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(50)
