# %% [markdown]
# # 040223101 การเขียนโปรแกรมคอมพิวเตอร์สำหรับคณิตศาสตร์ 1
# ## (Computer Programming for Mathematics 1)
#
# # แบบฝึกหัด บทที่ 8: ดิกชันนารีและเซต
# ### Dictionaries and Sets
#
# **ผู้สอน:** รศ.ดร.อนุชิต จิตพัฒนกุล
# ภาควิชาคณิตศาสตร์ คณะวิทยาศาสตร์ประยุกต์  มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าพระนครเหนือ
#
# ---
#
# ### 📝 คำชี้แจง
# - ให้นักศึกษาเขียนโปรแกรมภาษา Python แก้โจทย์แต่ละข้อในเซลล์โค้ดที่เว้นว่างไว้ใต้โจทย์
# - กดปุ่ม **▶ Run** (หรือ Shift+Enter) เพื่อรันโค้ดและตรวจผลลัพธ์
# - โจทย์แบ่งเป็น 3 ระดับจากง่ายไปยาก ควรทำไล่ตามลำดับ
# - เขียนชื่อ-รหัสนักศึกษาของคุณในเซลล์ด้านล่างก่อนเริ่มทำ

# %%
# ✏️ กรอกข้อมูลของคุณ
student_name = ""   # ชื่อ-นามสกุล
student_id = ""     # รหัสนักศึกษา
print("ผู้ทำแบบฝึกหัด:", student_name, student_id)

# %% [markdown]
# ---
# ## ระดับที่ 1 — พื้นฐาน (Basic)
# _ฝึกใช้คำสั่งและไวยากรณ์พื้นฐานของบทนี้ให้คล่อง_

# %% [markdown]
# **ข้อ 1.** เขียนโปรแกรมสร้างดิกชันนารีเก็บชื่อและอายุ แล้วแสดงค่าอายุ

# %%
# ✍️ เขียนโค้ดข้อ 1 ที่นี่

# %% [markdown]
# **ข้อ 2.** เขียนโปรแกรมสร้างดิกชันนารี {'a':1, 'b':2, 'c':3} แล้วแสดงคีย์ทั้งหมด

# %%
# ✍️ เขียนโค้ดข้อ 2 ที่นี่

# %% [markdown]
# **ข้อ 3.** เขียนโปรแกรมสร้างดิกชันนารี {'a':1, 'b':2, 'c':3} แล้วแสดงค่าทั้งหมด

# %%
# ✍️ เขียนโค้ดข้อ 3 ที่นี่

# %% [markdown]
# **ข้อ 4.** เขียนโปรแกรมสร้างดิกชันนารีเก็บคะแนน 3 คน แล้วแสดงผลรวมของคะแนนทั้งหมด

# %%
# ✍️ เขียนโค้ดข้อ 4 ที่นี่

# %% [markdown]
# **ข้อ 5.** เขียนโปรแกรมสร้างดิกชันนารีว่าง แล้วเพิ่มคู่ 'x':10 และ 'y':20 จากนั้นแสดงทั้งหมด

# %%
# ✍️ เขียนโค้ดข้อ 5 ที่นี่

# %% [markdown]
# **ข้อ 6.** เขียนโปรแกรมสร้างดิกชันนารี {'a':1, 'b':2} แล้วเปลี่ยนค่าของ 'a' เป็น 100

# %%
# ✍️ เขียนโค้ดข้อ 6 ที่นี่

# %% [markdown]
# **ข้อ 7.** เขียนโปรแกรมสร้างดิกชันนารี แล้วตรวจว่ามีคีย์ 'name' หรือไม่

# %%
# ✍️ เขียนโค้ดข้อ 7 ที่นี่

# %% [markdown]
# **ข้อ 8.** เขียนโปรแกรมสร้างดิกชันนารี แล้วแสดงจำนวนคู่คีย์-ค่าด้วย len()

# %%
# ✍️ เขียนโค้ดข้อ 8 ที่นี่

# %% [markdown]
# **ข้อ 9.** เขียนโปรแกรมสร้างเซตจากลิสต์ [1,2,2,3,3,3] แล้วแสดงผล

# %%
# ✍️ เขียนโค้ดข้อ 9 ที่นี่

# %% [markdown]
# **ข้อ 10.** เขียนโปรแกรมหาจำนวนค่าที่ไม่ซ้ำในลิสต์ [3,1,4,1,5,9,2,6,5] ด้วยเซต

# %%
# ✍️ เขียนโค้ดข้อ 10 ที่นี่

# %% [markdown]
# **ข้อ 11.** เขียนโปรแกรมสร้างเซต {1,2,3} แล้วเพิ่มสมาชิก 4 ด้วย add

# %%
# ✍️ เขียนโค้ดข้อ 11 ที่นี่

# %% [markdown]
# **ข้อ 12.** เขียนโปรแกรมสร้างเซต {1,2,3,4} แล้วลบสมาชิก 2 ด้วย discard

# %%
# ✍️ เขียนโค้ดข้อ 12 ที่นี่

# %% [markdown]
# **ข้อ 13.** เขียนโปรแกรมหายูเนียนของเซต {1,2,3} กับ {3,4,5}

# %%
# ✍️ เขียนโค้ดข้อ 13 ที่นี่

# %% [markdown]
# **ข้อ 14.** เขียนโปรแกรมหาอินเตอร์เซกชันของเซต {1,2,3,4} กับ {3,4,5,6}

# %%
# ✍️ เขียนโค้ดข้อ 14 ที่นี่

# %% [markdown]
# **ข้อ 15.** เขียนโปรแกรมหาผลต่างของเซต {1,2,3,4,5} ลบ {2,4}

# %%
# ✍️ เขียนโค้ดข้อ 15 ที่นี่

# %% [markdown]
# **ข้อ 16.** เขียนโปรแกรมสร้างดิกชันนารี แล้วแสดงค่าของคีย์ 'b' โดยใช้ get

# %%
# ✍️ เขียนโค้ดข้อ 16 ที่นี่

# %% [markdown]
# **ข้อ 17.** เขียนโปรแกรมสร้างดิกชันนารี แล้วใช้ get หาค่าของคีย์ 'z' ที่ไม่มี (คืน 0)

# %%
# ✍️ เขียนโค้ดข้อ 17 ที่นี่

# %% [markdown]
# **ข้อ 18.** เขียนโปรแกรมวนแสดงคู่คีย์-ค่าทั้งหมดในดิกชันนารีด้วย items

# %%
# ✍️ เขียนโค้ดข้อ 18 ที่นี่

# %% [markdown]
# **ข้อ 19.** เขียนโปรแกรมตรวจว่าค่า 3 อยู่ในเซต {1,2,3,4,5} หรือไม่

# %%
# ✍️ เขียนโค้ดข้อ 19 ที่นี่

# %% [markdown]
# **ข้อ 20.** เขียนโปรแกรมสร้างดิกชันนารีเก็บราคาสินค้า 3 ชนิด แล้วแสดงราคาของสินค้าที่แพงที่สุด

# %%
# ✍️ เขียนโค้ดข้อ 20 ที่นี่

# %% [markdown]
# ---
# ## ระดับที่ 2 — ปานกลาง (Intermediate)
# _ประยุกต์ความรู้แก้โจทย์ที่ซับซ้อนขึ้นและผสมหลายแนวคิด_

# %% [markdown]
# **ข้อ 21.** เขียนโปรแกรมนับความถี่ของตัวอักษรในคำว่า mathematics

# %%
# ✍️ เขียนโค้ดข้อ 21 ที่นี่

# %% [markdown]
# **ข้อ 22.** เขียนโปรแกรมนับความถี่ของคำในประโยคที่รับเข้ามา (แยกด้วยช่องว่าง)

# %%
# ✍️ เขียนโค้ดข้อ 22 ที่นี่

# %% [markdown]
# **ข้อ 23.** เขียนโปรแกรมสร้างดิกชันนารีเก็บคะแนนนักศึกษา 3 คน แล้วแสดงชื่อคนที่ได้คะแนนสูงสุด

# %%
# ✍️ เขียนโค้ดข้อ 23 ที่นี่

# %% [markdown]
# **ข้อ 24.** เขียนโปรแกรมหาค่าเฉลี่ยของคะแนนในดิกชันนารี {'A':80,'B':90,'C':70}

# %%
# ✍️ เขียนโค้ดข้อ 24 ที่นี่

# %% [markdown]
# **ข้อ 25.** เขียนโปรแกรมหาจำนวนสมาชิกที่อยู่ทั้งในเซต A={1,2,3,4,5} และ B={3,4,5,6,7}

# %%
# ✍️ เขียนโค้ดข้อ 25 ที่นี่

# %% [markdown]
# **ข้อ 26.** เขียนโปรแกรมหาผลต่างสมมาตรของเซต {1,2,3,4} กับ {3,4,5,6}

# %%
# ✍️ เขียนโค้ดข้อ 26 ที่นี่

# %% [markdown]
# **ข้อ 27.** เขียนโปรแกรมสร้างดิกชันนารีจากสองลิสต์ ชื่อ ['a','b','c'] และคะแนน [80,90,70]

# %%
# ✍️ เขียนโค้ดข้อ 27 ที่นี่

# %% [markdown]
# **ข้อ 28.** เขียนโปรแกรมนับจำนวนสระในคำที่รับเข้ามา โดยใช้ดิกชันนารีเก็บความถี่ของแต่ละสระ

# %%
# ✍️ เขียนโค้ดข้อ 28 ที่นี่

# %% [markdown]
# **ข้อ 29.** เขียนโปรแกรมตรวจว่าเซต {1,2} เป็นสับเซตของ {1,2,3,4} หรือไม่

# %%
# ✍️ เขียนโค้ดข้อ 29 ที่นี่

# %% [markdown]
# **ข้อ 30.** เขียนโปรแกรมหาสมาชิกที่ปรากฏในลิสต์ทั้งสอง [1,2,3,4] และ [3,4,5,6] ด้วยเซต

# %%
# ✍️ เขียนโค้ดข้อ 30 ที่นี่

# %% [markdown]
# **ข้อ 31.** เขียนโปรแกรมสร้างดิกชันนารีนับจำนวนเลขคู่และเลขคี่ในลิสต์ [1,2,3,4,5,6,7]

# %%
# ✍️ เขียนโค้ดข้อ 31 ที่นี่

# %% [markdown]
# **ข้อ 32.** เขียนโปรแกรมลบคู่คีย์-ค่าที่คีย์ 'b' ออกจากดิกชันนารี {'a':1,'b':2,'c':3} ด้วย pop

# %%
# ✍️ เขียนโค้ดข้อ 32 ที่นี่

# %% [markdown]
# **ข้อ 33.** เขียนโปรแกรมหาคีย์ที่มีค่ามากที่สุดในดิกชันนารี {'a':5,'b':9,'c':3}

# %%
# ✍️ เขียนโค้ดข้อ 33 ที่นี่

# %% [markdown]
# **ข้อ 34.** เขียนโปรแกรมรวมดิกชันนารีสองตัว {'a':1,'b':2} กับ {'c':3,'d':4}

# %%
# ✍️ เขียนโค้ดข้อ 34 ที่นี่

# %% [markdown]
# **ข้อ 35.** เขียนโปรแกรมหาจำนวนตัวอักษรที่ไม่ซ้ำในคำว่า programming ด้วยเซต

# %%
# ✍️ เขียนโค้ดข้อ 35 ที่นี่

# %% [markdown]
# **ข้อ 36.** เขียนโปรแกรมตรวจว่าสองเซต {1,2,3} กับ {4,5,6} ไม่มีสมาชิกร่วมกันหรือไม่ (disjoint)

# %%
# ✍️ เขียนโค้ดข้อ 36 ที่นี่

# %% [markdown]
# **ข้อ 37.** เขียนโปรแกรมสร้างดิกชันนารีเก็บจำนวนครั้งที่แต่ละเลขปรากฏในลิสต์ [1,1,2,3,3,3]

# %%
# ✍️ เขียนโค้ดข้อ 37 ที่นี่

# %% [markdown]
# **ข้อ 38.** เขียนโปรแกรมหาผลรวมของค่าทั้งหมดในดิกชันนารีที่มีคีย์เป็นชื่อสินค้า ค่าเป็นราคา

# %%
# ✍️ เขียนโค้ดข้อ 38 ที่นี่

# %% [markdown]
# **ข้อ 39.** เขียนโปรแกรมแปลงลิสต์ที่มีค่าซ้ำ [5,3,5,2,3,1] เป็นลิสต์เรียงลำดับที่ไม่ซ้ำ

# %%
# ✍️ เขียนโค้ดข้อ 39 ที่นี่

# %% [markdown]
# **ข้อ 40.** เขียนโปรแกรมหาคีย์ทั้งหมดที่มีค่ามากกว่า 50 ในดิกชันนารี {'a':80,'b':40,'c':60}

# %%
# ✍️ เขียนโค้ดข้อ 40 ที่นี่

# %% [markdown]
# ---
# ## ระดับที่ 3 — ท้าทาย (Challenge)
# _โจทย์ประยุกต์เชิงคณิตศาสตร์และตรรกะที่ต้องคิดวิเคราะห์_

# %% [markdown]
# **ข้อ 41.** เขียนโปรแกรมนับความถี่ของคำในข้อความ แล้วแสดงคำที่ปรากฏบ่อยที่สุด

# %%
# ✍️ เขียนโค้ดข้อ 41 ที่นี่

# %% [markdown]
# **ข้อ 42.** เขียนโปรแกรมสร้างดิกชันนารีตารางสอบ (วิชา:คะแนน) แล้วแสดงวิชาที่ได้คะแนนต่ำสุดและสูงสุด

# %%
# ✍️ เขียนโค้ดข้อ 42 ที่นี่

# %% [markdown]
# **ข้อ 43.** เขียนโปรแกรมตรวจว่าข้อความสองข้อความเป็นแอนนาแกรมกันหรือไม่ (มีตัวอักษรเหมือนกัน)

# %%
# ✍️ เขียนโค้ดข้อ 43 ที่นี่

# %% [markdown]
# **ข้อ 44.** เขียนโปรแกรมหาสมาชิกที่อยู่ใน A หรือ B แต่ไม่อยู่ทั้งคู่ (ผลต่างสมมาตร) ของ {1,2,3,4,5} และ {4,5,6,7}

# %%
# ✍️ เขียนโค้ดข้อ 44 ที่นี่

# %% [markdown]
# **ข้อ 45.** เขียนโปรแกรมหาตัวอักษรที่ไม่ซ้ำตัวแรกในข้อความ (ปรากฏเพียงครั้งเดียว) ของคำว่า swiss

# %%
# ✍️ เขียนโค้ดข้อ 45 ที่นี่

# %% [markdown]
# **ข้อ 46.** เขียนโปรแกรมจัดกลุ่มเลขในลิสต์ [1,2,3,4,5,6,7,8] เป็นดิกชันนารี {'คู่':[...], 'คี่':[...]}

# %%
# ✍️ เขียนโค้ดข้อ 46 ที่นี่

# %% [markdown]
# **ข้อ 47.** เขียนโปรแกรมสร้างดิกชันนารีนับจำนวนนักศึกษาในแต่ละเกรดจากลิสต์เกรด ['A','B','A','C','B','A']

# %%
# ✍️ เขียนโค้ดข้อ 47 ที่นี่

# %% [markdown]
# **ข้อ 48.** เขียนโปรแกรมหาสมาชิกที่อยู่ในทั้งสามเซต A={1,2,3,4}, B={2,3,4,5}, C={3,4,5,6}

# %%
# ✍️ เขียนโค้ดข้อ 48 ที่นี่

# %% [markdown]
# **ข้อ 49.** เขียนโปรแกรมเรียงดิกชันนารี {'a':3,'b':1,'c':2} ตามค่าจากน้อยไปมาก แล้วแสดงคีย์ตามลำดับ

# %%
# ✍️ เขียนโค้ดข้อ 49 ที่นี่

# %% [markdown]
# **ข้อ 50.** เขียนโปรแกรมรับคะแนนนักศึกษาหลายคน (ชื่อและคะแนน) เก็บในดิกชันนารีจนกว่าจะป้อนชื่อว่าง แล้วแสดงค่าเฉลี่ย

# %%
# ✍️ เขียนโค้ดข้อ 50 ที่นี่
